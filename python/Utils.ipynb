# %% [markdown]
# ## Mesure du temps d'exécution : ```%%timeit``` et ```%timeit```
# Pour ```%%timeit``` la mesure du temps d'exécution va porter sur l'ensemble du code de la cellule (*cell mode*) alors que pour ```%timeit``` elle ne portera que sur la ligne suivant la déclaration (*line mode*).
#
# Le code va être exécuter *n.r* fois et le résultat va se présenter sous la forme : ```n loops, best of r : xxx ms per loop```. Comprendre : on a exécuté le code en *r* blocs de *n* exécutions. La meilleure série de n exécutions présente un temps moyen d'exécution de xxx ms. Pour ajuster les paramètres *r* et *n*, utiliser la syntaxe suivante :
#
# ```%%timeit -n 10 -r 3```
#
# *Attention* : *r* vaut 7 par défaut, *n* n'a pas de valeur par défaut fixe et suivant le bloc de code testé, sa valeur peut être très élevée (ex: 10 000 000).
#
# Attention il semble que ```%%timeit``` et ```%timeit``` wrappent le code à exécuter dans une fonction. Toutes les variables assignées dans la cellule à chronométrer vont donc l'être dans le scope local de cette fonction qui sera détruit à la fin de l'exécution. On ne pourra donc pas récupérer le produit des calculs assigné à ces variables.

# %%
# %%timeit -n 10 -r 5

str(1) == "1"
# Out:
# 10 loops, best of 5: 191 ns per loop

# %% [markdown]
# Il existe aussi un magic ```%%time```

# %% [markdown]
# ## Décorateur ```timer```

# %%
import time

# A changer avec Python 3.x où le formattage des strings change
def timer(f):
    def wrapper(*args, **kwargs):
        t1 = time.time()
        f(*args, **kwargs)
        duration = time.time()-t1
        print 'Total function runtime : %(hours)02dh%(mins)02dm%(secs)02ds%(ms)03dms' %\
        {'hours': duration//3600, 'mins': (duration%3600)//60, 'secs' : duration%60, 'ms' : (duration %1)*1000//1}
    return wrapper

# %%
@timer
def test_func(n):
    time.sleep(n)
    
test_func(2.365)
# Out:
# Total function runtime : 00h00m02s367ms

# %% [markdown]
# ## Spark ```gather``` function
# Equivalent Spark de ```pandas.melt``` ou de ```tidyr::gather``` pour ceux qui ont fait du R. Il s'agit de la fonction inverse d'un pivot. L'avantage est que dans ce sens et contrairement au pivot, l'opération ne nécessite pas de ```groupBy``` et donc de *shuffle*. Dis autrement, elle peut s'effectuer partition par partitions sans nécessiter d'échange d'informations entre les exécuteurs.
#
# **Remarque importante** : les valeurs destinées à se retrouver dans la même colonne doivent toutes être de même type. Il n'y a pas de conversion de type automatique. Par exemple, l'application de la fonction sur des colonnes mélangeant ```IntegerType()``` et ```FloatType()``` ne marchera pas.

# %%
def melt(df, var_col_name, val_col_name, pivot_col_name_list, drop_na):
    """
    Implements a melt operation in Spark (reverse pivot)
    :param df : Input Spark DataFrame (pyspak.sql.DataFrame)
    :param var_col_name : Name of the future columns that holds the names of all the melted columns (string)
    :param val_col_name : Name of the future columns that holds the values of all the melted columns (string)
    :param pivot_col_name_list : Names of the columns to melt (list of strings)
    :param drop_na : If True, drops NA values in val_col_name (boolean)
    """
    import pyspark.sql.functions as sqlf
    
    bcktk_pivot_col_name_list = ['`' + x.replace('`', '') + '`' for x in pivot_col_name_list]
    
    var_val_pairs = sqlf.array(*[sqlf.struct(sqlf.lit(var).alias(var_col_name), sqlf.col(var).alias(val_col_name)) 
                                 for var in bcktk_pivot_col_name_list])
    
    cols = [sqlf.col(name) for name in df.columns if '`' + name + '`' not in bcktk_pivot_col_name_list] + \
                [sqlf.col('_tmp_nested_col')[var_col_name].alias(var_col_name),
                sqlf.col('_tmp_nested_col')[val_col_name].alias(val_col_name)]
    
    melted_df = df.withColumn('_tmp_nested_col', sqlf.explode(var_val_pairs))\
            .select(*cols)\
            .withColumn(var_col_name, sqlf.regexp_replace(var_col_name, '`', ''))
            
    if drop_na:
        melted_df = melted_df.na.drop(subset=[val_col_name])
    
    return melted_df

# %% [markdown]
# Détails sur l'utilisation de ```explode``` :

# %%
columns = ['id', 'day']
vals = [(1, 2),
        (2, 2),
        (3, 2),
        (4, 2),
        (5, 2),
        (6, 2),
        (7, 4),
        (8, 4),
        (9, 4),
        (10, 4),
        (11, 4),
        (12, 5),
        (13, 5),
        (14, 5)]

# create DataFrame
dfe = spark.createDataFrame(vals, columns)\
        .withColumn('month', lit(9))\
        .withColumn('day', col('day').cast(IntegerType()))

# %%
dfe.select(
    col('id'),
    explode(array(struct(lit('day').alias('var_name'), col('day').alias('value')),
                 struct(lit('month').alias('var_name'), col('month').alias('value')))).alias('gather'))\
    .show()

# %%
tst = gather(dfe, 'sensor', 'value', ['day', 'month'])
tst.show()

# %% [markdown]
# ## Utilitaires Metastore Spark

# %%
def spark_list_tables():
    list_tables = spark.catalog.listTables()
    table_list_cols = ['tableName', 'database', 'description', 'tableType', 'isTemporary']
    return pd.DataFrame([dict(zip(table_list_cols, list(x))) for x in list_tables], columns=table_list_cols)

def spark_list_databases():
    list_db = spark.catalog.listDatabases()
    db_list_cols = ['dbName', 'description', 'locationUri']
    return pd.DataFrame([dict(zip(db_list_cols, list(x))) for x in list_db], columns=db_list_cols)

# %%
import subprocess
import pandas as pd

old_table_path = '/apps/hive/warehouse/historic_measurement'
test_list = [u'aircraft=a380/registration=F-HPJB/departure_year=2018/departure_month=1',
 u'aircraft=a380/registration=F-HPJB/departure_year=2018/departure_month=10',
 u'aircraft=a380/registration=F-HPJB/departure_year=2018/departure_month=2',
 u'aircraft=a380/registration=F-HPJB/departure_year=2018/departure_month=3',
 u'aircraft=a380/registration=F-HPJB/departure_year=2018/departure_month=4',
 u'aircraft=a380/registration=F-HPJB/departure_year=2018/departure_month=5',
 u'aircraft=a380/registration=F-HPJB/departure_year=2018/departure_month=6',
 u'aircraft=a380/registration=F-HPJB/departure_year=2018/departure_month=7',
 u'aircraft=a380/registration=F-HPJB/departure_year=2018/departure_month=8',
 u'aircraft=a380/registration=F-HPJB/departure_year=2018/departure_month=9']

records = []
for part in test_list:
    out = subprocess.check_output('hdfs dfs -count ' + old_table_path + '/' + part, shell=True)
    out_splt = [x for x in out.replace('\n', '').split(' ') if x != '']
    records.append(dict(zip(['file_nb', 'file_size_bytes', 'partition'], out_splt[1:])))
    
part_data = pd.DataFrame(records)\
    .assign(**{'file_nb' : lambda df : df['file_nb'].astype('int64'),
             'file_size_bytes' : lambda df : df['file_size_bytes'].astype('int64')})\
    .assign(**{'file_size_GiB' : lambda df : df['file_size_bytes']/(1024)**3})\
    .loc[:,['file_nb', 'file_size_bytes', 'file_size_GiB', 'partition']]
    
part_data
# Out:
#    file_nb  file_size_bytes  file_size_GiB  \
# 0     1716       1817447582       1.692630
# 1     2938       3366535298       3.135330
# 2     2739       3250229880       3.027012
# 3      382        324940148       0.302624
# 4     2652       3168396437       2.950799
# 5     2558       2975102376       2.770780
# 6     3034       3252658429       3.029274
# 7     3536       4183635325       3.896314
# 8     2586       2842847892       2.647608
# 9     3140       3596756801       3.349741
#
#                                            partition
# 0  /apps/hive/warehouse/historic_measurement/airc...
# 1  /apps/hive/warehouse/historic_measurement/airc...
# 2  /apps/hive/warehouse/historic_measurement/airc...
# 3  /apps/hive/warehouse/historic_measurement/airc...
# 4  /apps/hive/warehouse/historic_measurement/airc...
# 5  /apps/hive/warehouse/historic_measurement/airc...
# 6  /apps/hive/warehouse/historic_measurement/airc...
# 7  /apps/hive/warehouse/historic_measurement/airc...
# 8  /apps/hive/warehouse/historic_measurement/airc...
# 9  /apps/hive/warehouse/historic_measurement/airc...

# %%
for part in test_list[0:1]:
    out = subprocess.check_output('hdfs dfs -ls ' + old_table_path + '/' + part, shell=True)
    out_splt = [x for x in out.split('\n')]
    out_splt

# %% [markdown]
# ### Pretty print dict

# %%
def pprintDict(dc, i=0):
    for k, v in dc.items():
        if isinstance(v, dict):
            print '    '*i + '|-' + str(k)
            pprintDict(v, i+1)
        else:
            print '    '*i + '|-' + str(k) + ' : ' + str(v)

# %%
import os, json
dir_param = '/app/PROFILER/travail/pilienhart/Test_refactoring'

with open(os.path.join(dir_param, 'generate_param_ata28_pmp_dp.json'), "r") as f:
    d = json.load(f)

# %%
d['ata28_pmp_dp']['param']['load_pipeline']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-b7a9666eec6e> in <module>()
# ----> 1 d['ata28_pmp_dp']['param']['load_pipeline']
#
# TypeError: list indices must be integers, not str

# %%
for dc in d['ata28_pmp_dp'][0]['param']['load_pipeline']:
    pprintDict(dc)
# Out:
# |-function : merge_sar_with_meta
# |-module : profiler.load
# |-param
#     |-sensors : [u'_CURM_9QL1_3.2', u'FPMPBRITEN.1', u'FQWT.RM:1', u'FPMPARITPS.1', u'_CURM_9QL2_1.2', u'FQCC.4:1', u'FPMPBLITPS.1', u'_CURM_10QL1_3.2', u'FPMPBLITEN.1', u'FQFT.3:1', u'FQFT.4:1', u'FPMPBROTPS.1', u'_CURM_5QA1_2.2', u'FPMPF4MPS', u'_CURM_13QN2_3.1', u'_CURM_5QA1_3.2', u'FQWT.LI:1', u'_CURM_5QA4_3.1', u'FPMPF1MEN.1', u'_CURM_5QA4_2.1', u'_CURM_6QN2_1.1', u'FPMPBLOTPS.1', u'_CURM_11QL2_2.1', u'_CURM_804QA_2.2', u'FQCC.3:1', u'FPMPALITEN.1', u'FPMPF1MPS.1', u'_CURM_804QA_1.2', u'_CURM_5QA4_1.1', u'_CURM_11QL1_3.1', u'_CURM_20QN1_3.1', u'_CURM_804QA_3.2', u'FQCC.2:1', u'FPMPF4MEN', u'_CURM_13QN1_1.1', u'FPMPBLMTPS.1', u'_CURM_10QL2_3.2', u'FPMPBLOTEN.1', u'_CURM_5QA1_1.2', u'FPMPBLMTEN.1', u'FPMPALMTEN.1', u'FPMPBRITPS.1', u'FQFT.1:1', u'FPMP2TTPS.1', u'_CURM_20QN2_2.1', u'FQCC.1:1', u'FPMPARMTPS.1', u'FPMP2TTEN.1', u'FPMPBRMTPS.1', u'FPMPARMTEN.1', u'FPMPALMTPS.1', u'FPMPBROTEN.1', u'FPMPF3MEN.1', u'FPMPALITPS.1', u'FQTT:1', u'FQWT.LM:1', u'FQWT.RI:1', u'FPMPF3MPS.1', u'FPMPARITEN.1', u'FQWT.RO:1', u'FPMPBRMTEN.1', u'FQWT.LO:1']

# %%
with open(os.path.join(dir_param, 'global_settings.json'), "r") as f:
    dparam = json.load(f)

# %%
dparam.keys()
# Out:
# [u'prd', u'clean_mongo', u'ite', u'sparkparams', u'csv_to_parquet', u'cae']

# %%
pprintDict(dparam)
# Out:
# |-global_settings
#     |-prd
#         |-mongo_db : profiler
#         |-hive_measurement_table_name : measurement
#         |-hive_flight_table_name : flight
#         |-nb_days_hdfs_sliding_window_hive : 90
#         |-dir_fs_csv_a380 : /app/PROFILER/data/hdfs
#         |-dir_hdfs_resources : /user/profiler/resources
#         |-spark.local.dir : /app/PROFILER/tmp
#         |-nb_days_hdfs_sliding_window_csv : 3
#         |-dir_hdfs_csv : /user/profiler/csv
#         |-mongo_client : mongodb://PFI_O:Profil3rO@tlspbpfimg01.france.airfrance.fr:27017,tlspbpfimg02.france.airfrance.fr:27017/profiler?replicaSet=rs606
#     |-clean_mongo
#         |-aircraft
#             |-a380
#                 |-metainformations
#                     |-departure_date : departureDate
#                     |-equipment_name : equipmentName
#                     |-immat : registration
#                     |-time : time
#                 |-ata
#                     |-ata32
#                         |-equipment_type
#                             |-bws
#                                 |-collection : measurementsA380Ata32Bws
#                                 |-nb_flights_5_seconds : 0
#                                 |-nb_days_to_keep : 15
#                                 |-components : [u'lvdtCurL', u'lvdtCurR', u'svCurL', u'svCurR', u'bwsLockL', u'bwsLockR', u'bwsPrhiL', u'bwsPrhiR', u'bwsAngL', u'bwsAngR', u'bwsAngDL', u'bwsAngDR', u'nwsAngle']
#                             |-nws
#                                 |-collection : measurementsA380Ata32Nws
#                                 |-nb_flights_5_seconds : 0
#                                 |-nb_days_to_keep : 15
#                                 |-components : [u'rvdtCom', u'rvdtMon', u'angleCommand', u'servoValveCurrent', u'lvdt']
#                     |-ata28
#                         |-equipment_type
#                             |-prb
#                                 |-collection : measurementsA380Ata28Prb
#                                 |-nb_flights_5_seconds : 2
#                                 |-nb_days_to_keep : 10
#                                 |-components : [u'signal1A', u'signal1B', u'signal2A', u'signal2B', u'signal3A', u'signal3B', u'signal4A', u'signal4B', u'signal5A', u'signal5B', u'signal6A', u'signal6B', u'signal7A', u'signal7B', u'signal8A', u'signal8B', u'signal9A', u'signal9B', u'signal10A', u'signal10B']
#                             |-pmp
#                                 |-collection : measurementsA380Ata28Pmp
#                                 |-nb_flights_5_seconds : 2
#                                 |-nb_days_to_keep : 90
#                                 |-components : [u'fuelQuantity', u'energizedMode', u'currentIntensity', u'pressureSwitch']
#                             |-vlv
#                                 |-collection : measurementsA380Ata28Vlv
#                                 |-nb_flights_5_seconds : 10
#                                 |-nb_days_to_keep : 10
#                                 |-components : [u'command', u'open', u'shut']
#     |-ite
#         |-mongo_db : profiler
#         |-hive_measurement_table_name : measurement
#         |-hive_flight_table_name : flight
#         |-nb_days_hdfs_sliding_window_hive : 1825
#         |-dir_fs_csv_a380 : /app/PROFILER/data/hdfs
#         |-dir_hdfs_resources : /user/profiler/resources
#         |-spark.local.dir : /app/PROFILER/tmp
#         |-nb_days_hdfs_sliding_window_csv : 3
#         |-dir_hdfs_csv : /user/profiler/csv
#         |-mongo_client : mongodb://tlsdbpfimg01:27017/
#     |-csv_to_parquet
#         |-csv_delimiter : ;
#         |-remove_csv_files : True
#     |-spark
#         |-params
#             |-spark.executor.memory : 4g
#             |-spark.executor.instances : 6
#             |-spark.yarn.executor.memoryOverhead : 2048
#         |-mode : yarn-cluster
#         |-app_name : profiler
#     |-cae
#         |-mongo_db : profiler
#         |-hive_measurement_table_name : measurement
#         |-hive_flight_table_name : flight
#         |-nb_days_hdfs_sliding_window_hive : 60
#         |-dir_fs_csv_a380 : /app/PROFILER/data/hdfs
#         |-dir_hdfs_resources : /user/profiler/resources
#         |-spark.local.dir : /app/PROFILER/tmp
#         |-nb_days_hdfs_sliding_window_csv : 3
#         |-dir_hdfs_csv : /user/profiler/csv
#         |-mongo_client : mongodb://PFI_O:readwrite@tlsrbpfimg01.france.airfrance.fr:27017,tlsrbpfimg02.france.airfrance.fr:27017/profiler?replicaSet=rs605
# |-aircraft
#     |-a380
#         |-aircraft_settings
#             |-fs
#                 |-lst_immat : [u'F-HPJA', u'F-HPJB', u'F-HPJC', u'F-HPJD', u'F-HPJE', u'F-HPJF', u'F-HPJG', u'F-HPJH', u'F-HPJI', u'F-HPJJ']
#                 |-lst_sar_required : [17, 18, 25]
#             |-metainfos
#                 |-var_time : TIME
#                 |-first_meta_var : ACID_SNAP
#                 |-var_flt_id : $FLTLEGCNT_SNAP
#         |-module
#             |-ata28_m : [{u'module': u'profiler.framework', u'class': u'Preprocessing', u'param': {u'preprocessing_pipeline': [{u'function': u'filter_col', u'module': u'profiler.preprocessing', u'param': {u'list_selected_values': [u'17', u'18', u'25'], u'column_name': u'sar'}}, {u'function': u'filter_col', u'module': u'profiler.preprocessing', u'param': {u'list_selected_values': [u'FCAP7BWT.RO', u'FCAP7AWT.RO', u'FVLVALMTSH.1', u'FVLVBFT1C', u'FCAP7AWT.RM', u'FCAP4AWT.LO', u'FVLVAROTC', u'FCAP4BWT.LO', u'FPMPBROTPS.1', u'FVLVBLITSH.1', u'FQWT.RI:1', u'FCAP5BTT.R', u
u'module': u'profiler.preprocessing', u'param': {u'return_name': u'sar_sensor', u'column_name_1': u'sar', u'column_name_2': u'sensor'}}, {u'function': u'filter_col', u'module': u'profiler.preprocessing', u'param': {u'list_selected_values': [u'13_NWSANG:2', u'13_NWSAMON:1', u'13_NWSANGD:1', u'13_NWSSVLVDT:2', u'13_WLSPD.1:1', u'14_NWSSVCUR'], u'column_name': u'sar_sensor'}}, {u'function': u'cache', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_time_columns', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'mean_pivot_1s', u'module': u'profiler.preprocessing', u'param': {u'sensor_required': [u'NWSANG:2', u'NWSAMON:1', u'NWSANGD:1', u'NWSSVCUR', u'NWSSVLVDT:2', u'WLSPD.1:1']}}, {u'function': u'rename_col', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_time', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_unix_time', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'order_by', u'module': u'profiler.preprocessing', u'param': {u'column_name': u'time'}}, {u'function': u'flight_duration', u'module': u'profiler.preprocessing', u'param': {u'partition_by': [u'aircraft', u'registration', u'departure_year', u'departure_month', u'departure_day', u'flight_leg_count', u'phase']}}, {u'function': u'filter_on_column', u'module': u'profiler.preprocessing', u'param': {u'condition': u'>100', u'column_name': u'flight_duration'}}, {u'function': u'add_column_multiple_conditions', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'filter3deg', u'lst_condition': [u'>-3', u'<3'], u'lst_column_name': [u'NWSANG:2', u'NWSANG:2']}}, {u'function': u'add_column_operation_2_cols', u'module': u'profiler.preprocessing', u'param': {u'operation': u'-', u'return_name': u'diffComMon', u'column_name_1': u'NWSANG:2', u'column_name_2': u'NWSAMON:1'}}, {u'function': u'add_col_on_event', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'first_rising_spd', u'condition': u'>0', u'occurrence': u'first', u'partition_by': [u'aircraft', u'registration', u'departure_year', u'departure_month', u'departure_day', u'flight_leg_count', u'phase'], u'column_name': u'WLSPD.1:1'}}, {u'function': u'add_col_on_event', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'last_falling_spd', u'condition': u'>0', u'occurrence': u'last', u'partition_by': [u'aircraft', u'registration', u'departure_year', u'departure_month', u'departure_day', u'flight_leg_count', u'phase'], u'column_name': u'WLSPD.1:1'}}, {u'function': u'add_column_operation_2_cols', u'module': u'profiler.preprocessing', u'param': {u'operation': u'&', u'return_name': u'first_ris_last_fall', u'column_name_1': u'first_rising_spd', u'column_name_2': u'last_falling_spd'}}, {u'function': u'add_column_fwd_derivative', u'module': u'profiler.preprocessing', u'param': {u'freq': 1, u'return_name': u'der_COM', u'partition_by': [u'aircraft', u'registration', u'departure_year', u'departure_month', u'departure_day', u'flight_leg_count', u'phase'], u'column_name': u'NWSANG:2'}}, {u'function': u'std_scaler', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'NWSSVLVDT:2_std', u'column_name_cond': u'first_ris_last_fall', u'partition_by': [u'aircraft', u'registration', u'departure_year', u'departure_month', u'departure_day', u'flight_leg_count', u'phase'], u'column_name': u'NWSSVLVDT:2'}}, {u'function': u'std_scaler', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'NWSSVCUR_std', u'column_name_cond': u'first_ris_last_fall', u'partition_by': [u'aircraft', u'registration', u'departure_year', u'departure_month', u'departure_day', u'flight_leg_count', u'phase'], u'column_name': u'NWSSVCUR'}}, {u'function': u'std_scaler', u'module': u'profiler.preprocessing', u'param': {u'return_name': u
u'profiler.preprocessing', u'param': {u'lst_deltas': [{u'return_name': u'r11_delta_open', u'condition_var1': u'==1', u'variable_2': u'FVLVAFT1OP_1', u'variable_1': u'FVLVAFT1C', u'condition_var2': u'==0'}, {u'return_name': u'r11_delta_shut', u'condition_var1': u'==0', u'variable_2': u'FVLVAFT1OP_1', u'variable_1': u'FVLVAFT1C', u'condition_var2': u'==1'}, {u'return_name': u'r13_delta_open', u'condition_var1': u'==1', u'variable_2': u'FVLVBFT1OP_1', u'variable_1': u'FVLVBFT1C', u'condition_var2': u'==0'}, {u'return_name': u'r13_delta_shut', u'condition_var1': u'==0', u'variable_2': u'FVLVBFT1OP_1', u'variable_1': u'FVLVBFT1C', u'condition_var2': u'==1'}, {u'return_name': u'r21_delta_open', u'condition_var1': u'==1', u'variable_2': u'FVLVBLITOP', u'variable_1': u'FVLVBLITC', u'condition_var2': u'==0'}, {u'return_name': u'r21_delta_shut', u'condition_var1': u'==0', u'variable_2': u'FVLVBLITOP', u'variable_1': u'FVLVBLITC', u'condition_var2': u'==1'}, {u'return_name': u'r23_delta_open', u'condition_var1': u'==1', u'variable_2': u'FVLVBFT2OP_1', u'variable_1': u'FVLVBFT2C', u'condition_var2': u'==0'}, {u'return_name': u'r23_delta_shut', u'condition_var1': u'==0', u'variable_2': u'FVLVBFT2OP_1', u' ...
#             |-ata32_lg : [{u'module': u'profiler.framework', u'class': u'Preprocessing', u'param': {u'preprocessing_pipeline': [{u'function': u'filter_col', u'module': u'profiler.preprocessing', u'param': {u'list_selected_values': [u'LGRIGA4A.1', u'LGRIGB4A.1', u'LGRIGA4B.1', u'LGRIGB4B.1', u'LGRIGA4A.2', u'LGRIGB4A.2', u'LGRIGA4B.2', u'LGRIGB4B.2', u'LGRIGA4A.3', u'LGRIGB4A.3', u'LGRIGA4B.3', u'LGRIGB4B.3', u'LGRIGA4A.4', u'LGRIGB4A.4', u'LGRIGA4B.4', u'LGRIGB4B.4', u'LGRIGA4A.5', u'LGRIGB4A.5', u'LGRIGA4B.5', u'LGRIGB4B.5', u'LGRIGA4A.6', u'LGRIGB4A.6', u'LGRIGA4B.6', u'LGRIGB4B.6', u'LGRIGA4A.7', u'LGRIGB4A.7', u'LGRIGA4B.7', u'LGRIGB4B.7', u'LGRIGA4A.8', u'LGRIGB4A.8', u'LGRIGA4B.8', u'LGRIGB4B.8', u'LGRIGA4A.9', u'LGRIGB4A.9', u'LGRIGA4B.9', u'LGRIGB4B.9', u'LGRIGA4A.10', u'LGRIGB4A.10', u'LGRIGA4B.10', u'LGRIGB4B.10', u'LGRIGA4A.15', u'LGRIGB4A.15', u'LGRIGA4B.15', u'LGRIGB4B.15', u'LGRIGA4A.16', u'LGRIGB4A.16', u'LGRIGA4B.16', u'LGRIGB4B.16', u'LGRIGA4A.17', u'LGRIGB4A.17', u'LGRIGA4B.17', u'LGRIGB4B.17', u'LGRIGA4A.18', u'LGRIGB4A.18', u'LGRIGA4B.18', u'LGRIGB4B.18', u'LGRIGA4A.19', u'LGRIGB4A.19', u'LGRIGA4B.19', u'LGRIGB4B.19', u'LGRIGA4A.20', u'LGRIGB4A.20', u'LGRIGA4B.20', u'LGRIGB4B.20', u'LGRIGA4A.21', u'LGRIGB4A.21', u'LGRIGA4B.21', u'LGRIGB4B.21', u'LGRIGA4A.22', u'LGRIGB4A.22', u'LGRIGA4B.22', u'LGRIGB4B.22', u'LGRIGA4A.23', u'LGRIGB4A.23', u'LGRIGA4B.23', u'LGRIGB4B.23', u'LGRIGA4A.24', u'LGRIGB4A.24', u'LGRIGA4B.24', u'LGRIGB4B.24', u'LGRIGA4A.25', u'LGRIGB4A.25', u'LGRIGA4B.25', u'LGRIGB4B.25', u'LGRIGA4A.34', u'LGRIGB4A.34', u'LGRIGA4B.34', u'LGRIGB4B.34', u'LGRIGA4A.35', u'LGRIGB4A.35', u'LGRIGA4B.35', u'LGRIGB4B.35', u'LGRIGA4A.36', u'LGRIGB4A.36', u'LGRIGA5A.1', u'LGRIGB5A.1', u'LGRIGA5B.1', u'LGRIGB5B.1', u'LGRIGA5A.5', u'LGRIGB5A.5', u'LGRIGA5B.5', u'LGRIGB5B.5', u'LGRIGA5A.6', u'LGRIGB5A.6', u'LGRIGA5B.6', u'LGRIGB5B.6', u'LGRIGA5A.7', u'LGRIGB5A.7', u'LGRIGA5B.7', u'LGRIGB5B.7', u'LGRIGA5A.8', u'LGRIGB5A.8', u'LGRIGA5B.8', u'LGRIGB5B.8', u'LGRIGA5A.9', u'LGRIGB5A.9', u'LGRIGA5B.9', u'LGRIGB5B.9', u'LGRIGA5A.10', u'LGRIGB5A.10', u'LGRIGA5B.10', u'LGRIGB5B.10', u'LGRIGA5A.11', u'LGRIGB5A.11', u'LGRIGA5B.11', u'LGRIGB5B.11', u'LGRIGA5A.16', u'LGRIGB5A.16', u'LGRIGA5B.16', u'LGRIGB5B.16', u'LGRIGA5A.17', u'LGRIGB5A.17', u'LGRIGA5B.17', u'LGRIGB5B.17', u'LGRIGA5A.18', u'LGRIGB5A.18', u'LGRIGA5B.18', u'LGRIGB5B.18', u'LGRIGA5A.19', u'LGRIGB5A.19', u'LGRIGA5B.19', u'LGRIGB5B.19', u'LGRIGA5A.20', u'LGRIGB5A.20', u'LGRIGA5B.20', u'LGRIGB5B.20', u'LGRIGA5A.21', u'LGRIGB5A.21', u'LGRIGA5B.21', u'LGRIGB5B.21', u'LGRIGA5A.22', u'LGRIGB5A.22', u'LGRIGA5B.22', u'LGRIGB5B.22', u'LGRIGA5A.23', u'LGRIGB5A.23', u'LGRIGA5B.23', u'LGRIGB5B.23', u'LGRIGA5A.24', u'LGRIGB5A.24', u'LGRIGA5B.24', u'LGRIGB5B.24', u'LGRIGA5A.25', u'LGRIGB5A.25', u'LGRIGA5B.25', u'LGRIGB5B.25', u'LGRIGA5A.28', u'LGRIGB5A.28', u'LGRIGA5B.28', u'LGRIGB5B.28', u'LGRIGA5A.29', u'LGRIGB5A.29', u'LGRIGA5B.29', u'LGRIGB5B.29', u'LGRIGA5A.30', u'LGRIGB5A.30', u'LGRIGA5B.30', u'LGRIGB5B.30', u'LGRIGA5A.31', u'LGRIGB5A.31', u'LGRIGA5B.31', u'LGRIGB5B.31', u'LGRIGA5A.35', u'LGRIGB5A.35', u'LGRIGA5B.35', u'LGRIGB5B.35', u'LGRIGA5A.36', u'LGRIGB5A.36', u'LGRIGA5B.36', u'LGRIGB5B.36'], u'column_name': u'sensor'}}, {u'function': u'filter_on_column', u'module': u'profiler.preprocessing', u'param': {u'condition': u'==5070', u'column_name': u'phase'}}, {u'function': u'add_time_columns', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'mean_pivot_1s', u'module': u'profiler.preprocessing', u'param': {u'sensor_required': [u'LGRIGA4A.1', u'LGRIGB4A.1', u'LGRIGA4B.1', u'LGRIGB4B.1', u'LGRIGA4A.2', u'LGRIGB4A.2', u'LGRIGA4B.2', u'LGRIGB4B.2', u'LGRIGA4A.3', u'LGRIGB4A.3', u'LGRIGA4B.3', u'LGRIGB4B.3', u'LGRIGA4A.4', u'LGRIGB4A.4', u'LGRIGA4B.4', u'LGRIGB4B.4', u'LGRIGA4A.5', u'LGRIGB4A.5', u'LGRIGA4B.5', u'LGRIGB4B.5', u'LGRIGA4A.6', u'LGRIGB4A.6', u'LGRIGA4B.6', u'LGRIGB4B.6', u'LGRIGA4A.7', u'LGRIGB4A.7', u'LGRIGA4B.7', u'LGRIGB4B.7', u'LGRIGA4A. ...
#             |-ata28_pmp_dp : [{u'module': u'profiler.framework', u'class': u'Preprocessing', u'param': {u'preprocessing_pipeline': [{u'function': u'filter_col', u'module': u'profiler.preprocessing', u'param': {u'list_selected_values': [u'17', u'18'], u'column_name': u'sar'}}, {u'function': u'filter_col', u'module': u'profiler.preprocessing', u'param': {u'list_selected_values': [u'_CURM_9QL1_3.2', u'FPMPBRITEN.1', u'FQWT.RM:1', u'FPMPARITPS.1', u'_CURM_9QL2_1.2', u'FQCC.4:1', u'FPMPBLITPS.1', u'_CURM_10QL1_3.2', u'FPMPBLITEN.1', u'FQFT.3:1', u'FQFT.4:1', u'FPMPBROTPS.1', u'_CURM_5QA1_2.2', u'FPMPF4MPS', u'_CURM_13QN2_3.1', u'_CURM_5QA1_3.2', u'FQWT.LI:1', u'_CURM_5QA4_3.1', u'FPMPF1MEN.1', u'_CURM_5QA4_2.1', u'_CURM_6QN2_1.1', u'FPMPBLOTPS.1', u'_CURM_11QL2_2.1', u'_CURM_804QA_2.2', u'FQCC.3:1', u'FPMPALITEN.1', u'FPMPF1MPS.1', u'_CURM_804QA_1.2', u'_CURM_5QA4_1.1', u'_CURM_11QL1_3.1', u'_CURM_20QN1_3.1', u'_CURM_804QA_3.2', u'FQCC.2:1', u'FPMPF4MEN', u'_CURM_13QN1_1.1', u'FPMPBLMTPS.1', u'_CURM_10QL2_3.2', u'FPMPBLOTEN.1', u'_CURM_5QA1_1.2', u'FPMPBLMTEN.1', u'FPMPALMTEN.1', u'FPMPBRITPS.1', u'FQFT.1:1', u'FPMP2TTPS.1', u'_CURM_20QN2_2.1
u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_time', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_unix_time', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'order_by', u'module': u'profiler.preprocessing', u'param': {u'column_name': u'time'}}, {u'function': u'add_flight_chrono', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'flight_chrono', u'partition_by': [u'registration', u'departure_year', u'departure_month', u'departure_day', u'flight_leg_count']}}, {u'function': u'flight_duration', u'module': u'profiler.preprocessing', u'param': {u'partition_by': [u'aircraft', u'registration', u'departure_year', u'departure_month', u'departure_day', u'flight_leg_count', u'phase']}}, {u'function': u'add_column_operation_2_cols', u'module': u'profiler.preprocessing', u'param': {u'operation': u'-', u'return_name': u'DIFF_0', u'column_name_1': u'TIREPR.NR', u'column_name_2': u'TIREPR.NL'}}, {u'function': u'add_column_operation_2_cols', u'module': u'profiler.preprocessing', u'param': {u'operation': u'-', u'return_name': u'DIFF_1', u'column_name_1': u'TIREPR.1', u'column_name_2': u'TIREPR.2'}}, {u'function': u'add_column_operation_2_cols', u'module': u'profiler.preprocessing', u'param': {u'operation': u'-', u'return_name': u'DIFF_2', u'column_name_1': u'TIREPR.3', u'column_name_2': u'TIREPR.4'}}, {u'function': u'add_column_operation_2_cols', u'module': u'profiler.preprocessing', u'param': {u'operation': u'-', u'return_name': u'DIFF_3', u'column_name_1': u'TIREPR.5', u'column_name_2': u'TIREPR.6'}}, {u'function': u'add_column_operation_2_cols', u'module': u'profiler.preprocessing', u'param': {u'operation': u'-', u'retu ...
#             |-ata35 : [{u'module': u'profiler.framework', u'class': u'Preprocessing', u'param': {u'preprocessing_pipeline': [{u'function': u'filter_col', u'module': u'profiler.preprocessing', u'param': {u'list_selected_values': [u'23'], u'column_name': u'sar'}}, {u'function': u'filter_col', u'module': u'profiler.preprocessing', u'param': {u'list_selected_values': [u'OXPAXP.1', u'OXPAXP.2', u'OXPAXP.3', u'OXPAXP.4', u'OXPAXP.5', u'OXPAXP.6', u'OXPAXP.7', u'OXCREWP.1', u'PAXOXMIN', u'CREWOXMIN', u'OXPAXT.1', u'OXPAXT.2', u'OXCREWT', u'OXPAXAVP', u'OXCREWAVP'], u'column_name': u'sensor'}}, {u'function': u'cache', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_time_columns', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'mean_pivot_1s', u'module': u'profiler.preprocessing', u'param': {u'sensor_required': [u'OXPAXP.1', u'OXPAXP.2', u'OXPAXP.3', u'OXPAXP.4', u'OXPAXP.5', u'OXPAXP.6', u'OXPAXP.7', u'OXCREWP.1', u'PAXOXMIN', u'CREWOXMIN', u'OXPAXT.1', u'OXPAXT.2', u'OXCREWT', u'OXPAXAVP', u'OXCREWAVP']}}, {u'function': u'rename_col', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_time', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_unix_time', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_flight_chrono', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'flight_chrono', u'partition_by': [u'aircraft', u'registration', u'departure_year', u'departure_month', u'departure_day', u'flight_leg_count']}}, {u'function': u'add_column_condition', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'TIME_5S', u'condition': u'%5 == 0', u'column_name': u'flight_chrono'}}, {u'function': u'order_by', u'module': u'profiler.preprocessing', u'param': {u'column_name': u'time'}}, {u'function': u'flight_duration', u'module': u'profiler.preprocessing', u'param': {u'partition_by': [u'aircraft', u'registration', u'departure_year', u'departure_month', u'departure_day', u'flight_leg_count']}}, {u'function': u'filter_on_column', u'module': u'profiler.preprocessing', u'param': {u'condition': u'>100', u'column_name': u'flight_duration'}}]}}, {u'module': u'profiler.framework', u'class': u'Aggregate', u'param': {u'aggregate_functions_spark': [{u'function': u'agg_min', u'module': u'profiler.aggregators', u'param': {u'result_name': u'departure_time_date', u'variable': u'time'}}, {u'function': u'agg_min', u'module': u'profiler.aggregators', u'param': {u'result_name': u'minoxpaxp1', u'variable': u'OXPAXP_1'}}, {u'function': u'agg_min', u'module': u'profiler.aggregators', u'param': {u'result_name': u'minoxpaxp2', u'variable': u'OXPAXP_2'}}, {u'function': u'agg_min', u'module': u'profiler.aggregators', u'param': {u'result_name': u'minoxpaxp3', u'variable': u'OXPAXP_3'}}, {u'function': u'agg_min', u'module': u'profiler.aggregators', u'param': {u'result_name': u'minoxpaxp4', u'variable': u'OXPAXP_4'}}, {u'function': u'agg_min', u'module': u'profiler.aggregators', u'param': {u'result_name': u'minoxpaxp5', u'variable': u'OXPAXP_5'}}, {u'function': u'agg_min', u'module': u'profiler.aggregators', u'param': {u'result_name': u'minoxpaxp6', u'variable': u'OXPAXP_6'}}, {u'function': u'agg_min', u'module': u'profiler.aggregators', u'param': {u'result_name': u'minoxpaxp7', u'variable': u'OXPAXP_7'}}, {u'function': u'agg_min', u'module': u'profiler.aggregators', u'param': {u'result_name': u'minOxCrewP1', u'variable': u'OXCREWP_1'}}, {u'function': u'collect_list', u'module': u'profiler.aggregators', u'param': {u'result_name': u'OxPaxPres1', u'variable': u'OXPAXP.1', u'column_name_cond': u'TIME_5S'}}, {u'function': u'collect_list', u'module': u'profiler.aggregators', u'param': {u'result_name': u'OxPaxPres2', u'variable': u'OXPAXP.2', u'column_name_cond': u'TIME_5S'}}, {u'function': u'collect_list', u'module': u'profiler.aggregators', u'param': {u'result_name': u'OxPaxPres3', u'variable': u'OXPAXP.3', u'column_name_cond': u'TIME_5S'} ...
#             |-ata21 : [{u'module': u'profiler.framework', u'class': u'Preprocessing', u'param': {u'preprocessing_pipeline': [{u'function': u'add_column_concat', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'sar_sensor', u'column_name_1': u'sar', u'column_name_2': u'sensor'}}, {u'function': u'filter_col', u'module': u'profiler.preprocessing', u'param': {u'list_selected_values': [u'56_!COMPDISCP_1.1:1', u'56_!COMPDISCP_2.1:2', u'56_!COMPDISCT_1.1:1', u'56_!COMPDISCT_2.1:2', u'56_!COMPSPEED_1.1:1', u'56_!COMPSPEED_2.1:2', u'56_!COMPSUCTP_1.1:1', u'56_!COMPSUCTP_2.1:2', u'56_!COMPSUCTT_1.1:1', u'56_!COMPSUCTT_2.1:2', u'56_!COOLSUPT_1.1:1', u'56_!COOLSUPT_2.1:2', u'56_!FANASPEED_1.1:1', u'56_!FANASPEED_2.1:2', u'56_!FANBSPEED_1.1:1', u'56_!FANBSPEED_2.1:2', u'56_!PUMP11SP_1.1:1', u'56_!PUMP12SP_2.1:1', u'56_!PUMP21SP_1.1:2', u'56_!PUMP22SP_2.1:2', u'56_!PUMPDISCP_1.1:1', u'56_!PUMPDISCP_2.1:2', u'56_!PUMPDISCT_1.1:1', u'56_!PUMPDISCT_2.1:2', u'56_!PUMPSUCTP_1.1:1', u'56_!PUMPSUCTP_2.1:2', u'56_!PUMPSUCTT_1.1:1', u'56_!PUMPSUCTT_2.1:2', u'56_!RACAPOS_1.1:1', u'56_!RACAPOS_2.1:2', u'56_!RESLEVEL_1.1:1', u'56_!RESLEVEL_2.1:2', u'56_!LOOP2INOP.1:2', u'56_!LOOP1INOP.1:1', u'56_FPFWS:1', u'56_TAT:1'], u'column_name': u'sar_sensor'}}, {u'function': u'cache', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_time_columns', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'mean_pivot_1s', u'module': u'profiler.preprocessing', u'param': {u'sensor_required': [u'!COMPDISCP_1.1:1', u'!COMPDISCP_2.1:2', u'!COMPDISCT_1.1:1', u'!COMPDISCT_2.1:2', u'!COMPSPEED_1.1:1', u'!COMPSPEED_2.1:2', u'!COMPSUCTP_1.1:1', u'!COMPSUCTP_2.1:2', u'!COMPSUCTT_1.1:1', u'!COMPSUCTT_2.1:2', u'!COOLSUPT_1.1:1', u'!COOLSUPT_2.1:2', u'!FANASPEED_1.1:1', u'!FANASPEED_2.1:2', u'!FANBSPEED_1.1:1', u'!FANBSPEED_2.1:2', u'!PUMP11SP_1.1:1', u'!PUMP12SP_2.1:1', u'!PUMP21SP_1.1:2', u'!PUMP22SP_2.1:2', u'!PUMPDISCP_1.1:1', u'!PUMPDISCP_2.1:2', u'!PUMPDISCT_1.1:1', u'!PUMPDISCT_2.1:2', u'!PUMPSUCTP_1.1:1', u'!PUMPSUCTP_2.1:2', u'!PUMPSUCTT_1.1:1', u'!PUMPSUCTT_2.1:2', u'!RACAPOS_1.1:1', u'!RACAPOS_2.1:2', u'!RESLEVEL_1.1:1', u'!RESLEVEL_2.1:2', u'!LOOP2INOP.1:2', u'!LOOP1INOP.1:1', u'TAT:1', u'FPFWS:1']}}, {u'function': u'rename_col', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_time', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_unix_time', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'order_by', u'module': u'profiler.preprocessing', u'param': {u'column_name': u'time'}}, {u'function': u'flight_duration', u'module': u'profiler.preprocessing', u'param': {u'partition_by': [u'aircraft', u'registration', u'departure_year', u'departure_month', u'departure_day', u'flight_leg_count']}}, {u'function': u'add_column_condition_integer', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'filght_sup100', u'condition': u' > 100', u'column_name': u'flight_duration'}}, {u'function': u'add_flight_chrono', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'chrono', u'partition_by': [u'aircraft', u'registration', u'departure_year', u'departure_month', u'departure_day', u'flight_leg_count']}}, {u'function': u'add_column_operation', u'module': u'profiler.preprocessing', u'param': {u'operation': u'%10', u'return_name': u'mod_samp', u'column_name': u'chrono'}}, {u'function': u'add_column_condition', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'mod_samp_bool', u'condition': u'==0', u'column_name': u'mod_samp'}}, {u'function': u'add_column_multiple_conditions', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'bool_coolsup_fl_len1', u'lst_condition': [u'>=-9.5', u'<=-8.5', u'>=10800'], u'lst_column_name': [u'!COOLSUPT_1.1:1', u'!COOLSUPT_1.1:1', u'chrono']}}, {u'function': u'add_column_multiple_conditions', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'bool_coolsup_fl_len2',  ...
#             |-ata36 : [{u'module': u'profiler.framework', u'class': u'Preprocessing', u'param': {u'preprocessing_pipeline': [{u'function': u'filter_col', u'module': u'profiler.preprocessing', u'param': {u'list_selected_values': [u'24'], u'column_name': u'sar'}}, {u'function': u'filter_col', u'module': u'profiler.preprocessing', u'param': {u'list_selected_values': [u'_RT_XFEED_B_R.4', u'_RT_XFEED_B_I.4', u'_RT_XFEED_A_R.4', u'_RT_XFEED_A_I.4', u'_RT_IR_WG_B_R.4', u'_RT_IR_WG_B_I.4', u'_RT_IR_WG_A_R.4', u'_RT_IR_WG_A_I.4', u'_RT_AGU_B_R.4', u'_RT_AGU_B_I.4', u'_RT_AGU_A_R.4', u'_RT_AGU_A_I.4', u'_RIGHT_WG_B_R.4', u'_RIGHT_WG_B_I.4', u'_RIGHT_WG_A_R.4', u'_RIGHT_WG_A_I.4', u'_OS_RU_TRMB_R.4', u'_OS_RU_TRMB_I.4', u'_OS_RU_TRMA_R.4', u'_OS_RU_TRMA_I.4', u'_OS_RL_TRMB_R.4', u'_OS_RL_TRMB_I.4', u'_OS_RL_TRMA_R.4', u'_OS_RL_TRMA_I.4', u'_OS_PY_4B_R.4', u'_OS_PY_4B_I.4', u'_OS_PY_4A_R.4', u'_OS_PY_4A_I.4', u'_OS_PY_3B_R.4', u'_OS_PY_3B_I.4', u'_OS_PY_3A_R.4', u'_OS_PY_3A_I.4', u'_OS_PY_2B_R.4', u'_OS_PY_2B_I.4', u'_OS_PY_2A_R.4', u'_OS_PY_2A_I.4', u'_OS_PY_1B_R.4', u'_OS_PY_1B_I.4', u'_OS_PY_1A_R.4', u'_OS_PY_1A_I.4', u'_OS_LU_TRMB_R.4', u'_OS_LU_TRMB_I.4', u'_OS_LU_TRMA_R.4', u'_OS_LU_TRMA_I.4', u'_OS_LL_TRMB_R.4', u'_OS_LL_TRMB_I.4', u'_OS_LL_TRMA_R.4', u'_OS_LL_TRMA_I.4', u'_OS_APU3_B_R.4', u'_OS_APU3_B_I.4', u'_OS_APU3_A_R.4', u'_OS_APU3_A_I.4', u'_OS_APU2_B_R.4', u'_OS_APU2_B_I.4', u'_OS_APU2_A_R.4', u'_OS_APU2_A_I.4', u'_OS_APU1_B_R.4', u'_OS_APU1_B_I.4', u'_OS_APU1_A_R.4', u'_OS_APU1_A_I.4', u'_LT_XFEED_B_R.4', u'_LT_XFEED_B_I.4', u'_LT_XFEED_A_R.4', u'_LT_XFEED_A_I.4', u'_LT_IR_WG_B_R.4', u'_LT_IR_WG_B_I.4', u'_LT_IR_WG_A_R.4', u'_LT_IR_WG_A_I.4', u'_LT_AGU_B_R.4', u'_LT_AGU_B_I.4', u'_LT_AGU_A_R.4', u'_LT_AGU_A_I.4', u'_LEFT_WG_B_R.4', u'_LEFT_WG_B_I.4', u'_LEFT_WG_A_R.4', u'_LEFT_WG_A_I.4', u'_FWD_CARG_B_R.4', u'_FWD_CARG_B_I.4', u'_FWD_CARG_A_R.4', u'_FWD_CARG_A_I.4'], u'column_name': u'sensor'}}, {u'function': u'cache', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_time_columns', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'max_pivot_1s', u'module': u'profiler.preprocessing', u'param': {u'sensor_required': [u'_RT_XFEED_B_R.4', u'_RT_XFEED_B_I.4', u'_RT_XFEED_A_R.4', u'_RT_XFEED_A_I.4', u'_RT_IR_WG_B_R.4', u'_RT_IR_WG_B_I.4', u'_RT_IR_WG_A_R.4', u'_RT_IR_WG_A_I.4', u'_RT_AGU_B_R.4', u'_RT_AGU_B_I.4', u'_RT_AGU_A_R.4', u'_RT_AGU_A_I.4', u'_RIGHT_WG_B_R.4', u'_RIGHT_WG_B_I.4', u'_RIGHT_WG_A_R.4', u'_RIGHT_WG_A_I.4', u'_OS_RU_TRMB_R.4', u'_OS_RU_TRMB_I.4', u'_OS_RU_TRMA_R.4', u'_OS_RU_TRMA_I.4', u'_OS_RL_TRMB_R.4', u'_OS_RL_TRMB_I.4', u'_OS_RL_TRMA_R.4', u'_OS_RL_TRMA_I.4', u'_OS_PY_4B_R.4', u'_OS_PY_4B_I.4', u'_OS_PY_4A_R.4', u'_OS_PY_4A_I.4', u'_OS_PY_3B_R.4', u'_OS_PY_3B_I.4', u'_OS_PY_3A_R.4', u'_OS_PY_3A_I.4', u'_OS_PY_2B_R.4', u'_OS_PY_2B_I.4', u'_OS_PY_2A_R.4', u'_OS_PY_2A_I.4', u'_OS_PY_1B_R.4', u'_OS_PY_1B_I.4', u'_OS_PY_1A_R.4', u'_OS_PY_1A_I.4', u'_OS_LU_TRMB_R.4', u'_OS_LU_TRMB_I.4', u'_OS_LU_TRMA_R.4', u'_OS_LU_TRMA_I.4', u'_OS_LL_TRMB_R.4', u'_OS_LL_TRMB_I.4', u'_OS_LL_TRMA_R.4', u'_OS_LL_TRMA_I.4', u'_OS_APU3_B_R.4', u'_OS_APU3_B_I.4', u'_OS_APU3_A_R.4', u'_OS_APU3_A_I.4', u'_OS_APU2_B_R.4', u'_OS_APU2_B_I.4', u'_OS_APU2_A_R.4', u'_OS_APU2_A_I.4', u'_OS_APU1_B_R.4', u'_OS_APU1_B_I.4', u'_OS_APU1_A_R.4', u'_OS_APU1_A_I.4', u'_LT_XFEED_B_R.4', u'_LT_XFEED_B_I.4', u'_LT_XFEED_A_R.4', u'_LT_XFEED_A_I.4', u'_LT_IR_WG_B_R.4', u'_LT_IR_WG_B_I.4', u'_LT_IR_WG_A_R.4', u'_LT_IR_WG_A_I.4', u'_LT_AGU_B_R.4', u'_LT_AGU_B_I.4', u'_LT_AGU_A_R.4', u'_LT_AGU_A_I.4', u'_LEFT_WG_B_R.4', u'_LEFT_WG_B_I.4', u'_LEFT_WG_A_R.4', u'_LEFT_WG_A_I.4', u'_FWD_CARG_B_R.4', u'_FWD_CARG_B_I.4', u'_FWD_CARG_A_R.4', u'_FWD_CARG_A_I.4']}}, {u'function': u'rename_col', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_time', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_unix_time', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u ...
#             |-ata32_bws : [{u'module': u'profiler.framework', u'class': u'Preprocessing', u'param': {u'preprocessing_pipeline': [{u'function': u'filter_col', u'module': u'profiler.preprocessing', u'param': {u'list_selected_values': [u'BWSSVLVDT.L', u'BWSSVLVDT.R', u'BWSSVCUR.L', u'BWSSVCUR.R', u'BWSLK1.L:1', u'BWSLK1.R:1', u'NWSANG:2', u'BWSANGD.L', u'BWSANGD.R', u'BWSANG.L', u'BWSANG.R', u'BWSPRHI.L:1', u'BWSPRHI.R:1'], u'column_name': u'sensor'}}, {u'function': u'cache', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_time_columns', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'mean_pivot_1s', u'module': u'profiler.preprocessing', u'param': {u'sensor_required': [u'BWSSVLVDT.L', u'BWSSVLVDT.R', u'BWSSVCUR.L', u'BWSSVCUR.R', u'BWSLK1.L:1', u'BWSLK1.R:1', u'NWSANG:2', u'BWSANGD.L', u'BWSANGD.R', u'BWSANG.L', u'BWSANG.R', u'BWSPRHI.L:1', u'BWSPRHI.R:1']}}, {u'function': u'rename_col', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_time', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'add_unix_time', u'module': u'profiler.preprocessing', u'param': {}}, {u'function': u'order_by', u'module': u'profiler.preprocessing', u'param': {u'column_name': u'time'}}, {u'function': u'flight_duration', u'module': u'profiler.preprocessing', u'param': {u'partition_by': [u'aircraft', u'registration', u'departure_year', u'departure_month', u'departure_day', u'flight_leg_count', u'phase']}}, {u'function': u'filter_on_column', u'module': u'profiler.preprocessing', u'param': {u'condition': u'>0', u'column_name': u'flight_duration'}}, {u'function': u'add_column_multiple_conditions', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'ang_lock0', u'lst_condition': [u'>-16', u'<16'], u'lst_column_name': [u'NWSANG:2', u'NWSANG:2']}}, {u'function': u'add_column_condition', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'ang_lock16pos', u'condition': u'>=16', u'column_name': u'NWSANG:2'}}, {u'function': u'add_column_condition', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'ang_lock16neg', u'condition': u'<=-16', u'column_name': u'NWSANG:2'}}, {u'function': u'add_column_operation_2_cols', u'module': u'profiler.preprocessing', u'param': {u'operation': u'|', u'return_name': u'ang_lock16', u'column_name_1': u'ang_lock16neg', u'column_name_2': u'ang_lock16pos'}}, {u'function': u'add_column_multiple_conditions', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'ang_lock1620neg', u'lst_condition': [u'>=-20', u'<=-16'], u'lst_column_name': [u'NWSANG:2', u'NWSANG:2']}}, {u'function': u'add_column_multiple_conditions', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'ang_lock1620pos', u'lst_condition': [u'>=16', u'<=20'], u'lst_column_name': [u'NWSANG:2', u'NWSANG:2']}}, {u'function': u'add_column_operation_2_cols', u'module': u'profiler.preprocessing', u'param': {u'operation': u'|', u'return_name': u'ang_lock1620', u'column_name_1': u'ang_lock1620pos', u'column_name_2': u'ang_lock1620neg'}}, {u'function': u'add_column_multiple_conditions', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'lock_1_16_l', u'lst_condition': [u'==1', u'==1'], u'lst_column_name': [u'BWSLK1_L:1', u'ang_lock16']}}, {u'function': u'add_column_multiple_conditions', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'lock_1_16_r', u'lst_condition': [u'==1', u'==1'], u'lst_column_name': [u'BWSLK1_R:1', u'ang_lock16']}}, {u'function': u'add_column_multiple_conditions', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'lock_0_l', u'lst_condition': [u'==0', u'==1'], u'lst_column_name': [u'BWSLK1_L:1', u'ang_lock0']}}, {u'function': u'add_column_multiple_conditions', u'module': u'profiler.preprocessing', u'param': {u'return_name': u'lock_1_1620_l', u'lst_condition': [u'==1', u'==1'], u'lst_column_name': [u'BWSLK1_L:1', u'ang_lock1620']}}, {u'function': u'add_column_mul ...

# %%
d.keys()
# Out:
# [u'prd', u'clean_mongo', u'ite', u'sparkparams', u'csv_to_parquet', u'cae']

# %%
not 'cae' in ['ite']
# Out:
# True

# %%
with open(os.path.join(dir_param, 'global_settings.json'), "r") as f:
    d = json.load(f)
    
pprintDict(d)
# Out:
# |-prd
#     |-mongo_db : profiler
#     |-dir_fs_csv_a380 : /app/PROFILER/data/hdfs
#     |-dir_hdfs_resources : /user/profiler/resources
#     |-spark.local.dir : /app/PROFILER/tmp
#     |-mongo_client : mongodb://PFI_O:Profil3rO@tlspbpfimg01.france.airfrance.fr:27017,tlspbpfimg02.france.airfrance.fr:27017/profiler?replicaSet=rs606
#     |-dir_hdfs_csv : /user/profiler/csv
#     |-data_storage : HDFS
#     |-output_storage : mongodb
# |-clean_mongo
#     |-aircraft
#         |-b777
#             |-metainformations
#                 |-departure_date : departureDate
#                 |-immat : registration
#                 |-time : acarsTime
#             |-ata
#                 |-ata28
#                     |-equipment_type
#                         |-datafuel
#                             |-collection : measurementsB777Ata28Datafuel
#                             |-nb_flights_30_min : 1
#                             |-components : [u'fuelTemp', u'fuelQtyLeft', u'fuelQtyCenter', u'fuelQtyRight', u'fuelQtyTotal', u'densityLeft', u'densityCenter', u'densityRight', u'fuelUsedLeft', u'fuelUsedRight', u'totalFuelUsed', u'fuelUsedDiff', u'crossfeedAft', u'crossfeedFwd', u'upliftDensity', u'upliftQty']
#                             |-nb_days_to_keep : 90
#                         |-fuelprobes
#                             |-collection : measurementsB777Ata28Fuelprobes
#                             |-nb_flights_30_min : 1
#                             |-components : [u'prbLeft1', u'prbLeft2', u'prbLeft3', u'prbLeft4', u'prbLeft5', u'prbLeft6', u'prbLeft7', u'prbLeft8', u'prbLeft9', u'prbLeft10', u'prbLeft11', u'prbLeft12', u'prbLeft13', u'prbLeft14', u'prbLeft15', u'prbLeft16', u'prbLeft17', u'prbLeft18', u'prbLeft19', u'prbLeft20', u'prbLeft21', u'prbLeft22', u'prbLeft23', u'prbLeft24', u'prbLeft25', u'prbLeft26', u'prbLeft27', u'prbLeft28', u'prbRight1', u'prbRight2', u'prbRight3', u'prbRight4', u'prbRight5', u'prbRight6', u'prbRight7', u'prbRight8', u'prbRight9', u'prbRight10', u'prbRight11', u'prbRight12', u'prbRight13', u'prbRight14', u'prbRight15', u'prbRight16', u'prbRight17', u'prbRight18', u'prbRight19', u'prbRight20', u'prbRight21', u'prbRight22', u'prbRight23', u'prbRight24', u'prbRight25', u'prbRight26', u'prbRight27', u'prbRight28', u'prbCenterLeft1', u'prbCenterRight1', u'prbCenterLeft2', u'prbCenterRight2', u'prbCenterLeft3', u'prbCenterRight3', u'prbCenterLeft4', u'prbCenterRight4', u'prbCenterLeft5', u'prbCenterRight5', u'prbCenterLeft6', u'prbCenterRight6', u'prbCenterLeft7', u'prbCenterRight7', u'prbCenterLeft8', u'prbCenterRight8', u'prbCenterLeft9', u'prbCenterRight9', u'prbCenterLeft10', u'prbCenterRight10']
#                             |-nb_days_to_keep : 10
# |-ite
#     |-mongo_db : profiler
#     |-dir_fs_csv_a380 : /app/PROFILER/data/hdfs
#     |-dir_hdfs_resources : /user/profiler/resources
#     |-spark.local.dir : /app/PROFILER/tmp
#     |-mongo_client : mongodb://tlsdbpfimg01:27017/
#     |-dir_hdfs_csv : /user/profiler/csv
#     |-data_storage : HDFS
#     |-output_storage : mongodb
# |-sparkparams : [[u'spark.app.name', u'Test_pl'], [u'spark.master', u'yarn'], [u'spark.yarn.queue', u'profiler'], [u'spark.sql.catalogImplementation', u'hive'], [u'spark.driver.extraJavaOptions', u'-Dlog4j.configuration=file:/app/PROFILER/travail/pilienhart/notes_perso/log4jDriverClientModeConsole.properties']]
# |-csv_to_parquet
#     |-csv_delimiter : ;
#     |-remove_csv_files : True
# |-cae
#     |-mongo_db : profiler
#     |-dir_fs_csv_a380 : /app/PROFILER/data/hdfs
#     |-dir_hdfs_resources : /user/profiler/resources
#     |-spark.local.dir : /app/PROFILER/tmp
#     |-mongo_client : mongodb://PFI_O:readwrite@tlsrbpfimg01.france.airfrance.fr:27017,tlsrbpfimg02.france.airfrance.fr:27017/profiler?replicaSet=rs605
#     |-dir_hdfs_csv : /user/profiler/csv
#     |-data_storage : HDFS
#     |-output_storage : mongodb

# %%
print 'PREPROCESSING PIPELINE'
for i, dc in enumerate(d[u'ata28_pmp_dp'][0]['param']['preprocessing_pipeline']):
    print 'Preprocessing function #' + str(i+1)
    pprintDict(dc)
    print dc['function'] + '('
    print '\n'

print 'AGGREGATE PIPELINE'
for i, dc in enumerate(d[u'ata28_pmp_dp'][1]['param']['aggregate_functions_spark']):
    print 'Aggregate function #' + str(i+1)
    pprintDict(dc)
    print '\n'
# Out:
# PREPROCESSING PIPELINE
# Preprocessing function #0
# |-function : add_unix_time
# |-param
# |-module : profiler.preprocessing
#
#
# Preprocessing function #1
# |-function : order_by_list
# |-param
#     |-column_name : [u'aircraft', u'registration', u'departure_date', u'flight_leg_count', u'time']
# |-module : profiler.preprocessing
#
#
# Preprocessing function #2
# |-function : flight_duration
# |-param
#     |-partition_by : [u'aircraft', u'registration', u'departure_date', u'flight_leg_count']
# |-module : profiler.preprocessing
#
#
# Preprocessing function #3
# |-function : add_flight_chrono
# |-param
#     |-return_name : _unix_time_from_start
#     |-partition_by : [u'aircraft', u'registration', u'departure_date', u'flight_leg_count']
# |-module : profiler.preprocessing
#
#
# Preprocessing function #4
# |-function : filter_on_column
# |-param
#     |-condition : >3600
#     |-column_name : flight_duration
# |-module : profiler.preprocessing
#
#
# Preprocessing function #5
# |-function : add_column_operation
# |-param
#     |-operation : * 0.1
#     |-return_name : start_progno_unix_time
#     |-column_name : flight_duration
# |-module : profiler.preprocessing
#
#
# Preprocessing function #6
# |-function : add_column_operation
# |-param
#     |-operation : * 0.9
#     |-return_name : end_progno_unix_time
#     |-column_name : flight_duration
# |-module : profiler.preprocessing
#
#
# Preprocessing function #7
# |-function : add_column_operation_2_cols
# |-param
#     |-operation : >=
#     |-return_name : filter_start_progno_unix_time
#     |-column_name_1 : _unix_time_from_start
#     |-column_name_2 : start_progno_unix_time
# |-module : profiler.preprocessing
#
#
# Preprocessing function #8
# |-function : add_column_operation_2_cols
# |-param
#     |-operation : <=
#     |-return_name : filter_end_progno_unix_time
#     |-column_name_1 : _unix_time_from_start
#     |-column_name_2 : end_progno_unix_time
# |-module : profiler.preprocessing
#
#
# Preprocessing function #9
# |-function : add_column_operation_2_cols
# |-param
#     |-operation : &
#     |-return_name : filter_common
#     |-column_name_1 : filter_start_progno_unix_time
#     |-column_name_2 : filter_end_progno_unix_time
# |-module : profiler.preprocessing
#
#
# Preprocessing function #10
# |-function : add_column_euclidean_quotient
# |-param
#     |-return_name : unix_time_quot_300
#     |-divisor : 300
#     |-column_name : unix_time
# |-module : profiler.preprocessing
#
#
# Preprocessing function #11
# |-function : noise_percentile
# |-param
#     |-column_name_cond : filter_common
#     |-window_length_second : 300
#     |-partition_by : [u'aircraft', u'registration', u'departure_date', u'flight_leg_count']
#     |-column_name_time : _unix_time_from_start
#     |-percentile : 90
#     |-return_name : noise_90_CURM_5QA4
#     |-column_name : _CURM_5QA4_1.1
# |-module : profiler.preprocessing
#
#
# Preprocessing function #12
# |-function : noise_percentile
# |-param
#     |-column_name_cond : filter_common
#     |-window_length_second : 300
#     |-partition_by : [u'aircraft', u'registration', u'departure_date', u'flight_leg_count']
#     |-column_name_time : _unix_time_from_start
#     |-percentile : 90
#     |-return_name : noise_90_CURM_5QA1
#     |-column_name : _CURM_5QA1_1.2
# |-module : profiler.preprocessing
#
#
# Preprocessing function #13
# |-function : rising_edges
# |-param
#     |-threshold_value : 0.2
#     |-column_name_cond : filter_common
#     |-window_length_second : 300
#     |-partition_by : [u'aircraft', u'registration', u'departure_date', u'flight_leg_count']
#     |-column_name_time : _unix_time_from_start
#     |-variable_2 : _CURM_5QA4_1.1
#     |-variable_1 : _CURM_5QA1_1.2
#     |-return_name : rising_edges_5qa1
#     |-column_euclidian_quotient : unix_time_quot_300
# |-module : profiler.preprocessing
#
#
# Preprocessing function #14
# |-function : rising_edges
# |-param
#     |-threshold_value : 0.2
#     |-column_name_cond : filter_common
#     |-window_length_second : 300
#     |-partition_by : [u'aircraft', u'registration', u'departure_date', u'flight_leg_count']
#     |-column_name_time : _unix_time_from_start
#     |-variable_2 : _CURM_5QA1_1.2
#     |-variable_1 : _CURM_5QA4_1.1
#     |-return_name : rising_edges_5qa4
#     |-column_euclidian_quotient : unix_time_quot_300
# |-module : profiler.preprocessing
#
#
# Preprocessing function #15
# |-function : add_true_if_first_occurence
# |-param
#     |-return_name : first_occurence_300
#     |-partition_by : [u'aircraft', u'registration', u'departure_date', u'flight_leg_count', u'unix_time_quot_300']
# |-module : profiler.preprocessing
#
#
# AGGREGATE PIPELINE
# Aggregate function #0
# |-function : count_condition
# |-param
#     |-result_name : risingEdgesNumber5qa1
#     |-variable : rising_edges_5qa1
#     |-condition_value : 0
#     |-column_name_cond : first_occurence_300
# |-module : profiler.aggregators
#
#
# Aggregate function #1
# |-function : count_condition
# |-param
#     |-result_name : risingEdgesNumber5qa4
#     |-variable : rising_edges_5qa4
#     |-condition_value : 0
#     |-column_name_cond : first_occurence_300
# |-module : profiler.aggregators
#
#
# Aggregate function #2
# |-function : agg_min
# |-param
#     |-result_name : noise5qa1
#     |-variable : noise_90_CURM_5QA1
#     |-column_name_cond : filter_common
# |-module : profiler.aggregators
#
#
# Aggregate function #3
# |-function : agg_min
# |-param
#     |-result_name : noise5qa4
#     |-variable : noise_90_CURM_5QA4
#     |-column_name_cond : filter_common
# |-module : profiler.aggregators
#
#
# Aggregate function #4
# |-function : agg_max
# |-param
#     |-result_name : maxRisingEdges5qa1
#     |-variable : rising_edges_5qa1
#     |-column_name_cond : filter_common
# |-module : profiler.aggregators
#
#
# Aggregate function #5
# |-function : agg_max
# |-param
#     |-result_name : maxRisingEdges5qa4
#     |-variable : rising_edges_5qa4
#     |-column_name_cond : filter_common
# |-module : profiler.aggregators

# %%
def rebuild_func(dct):
    if not dct['param']:
        return '.pipe(' + dct['function'] + ')'
    
    return '.pipe(partial(' + ','.join([dct['function']] + [k + '=' + str(v) for k, v in dct['param'].items()]) + '))'

# %%
print 'df\\'
for i, dc in enumerate(d[u'ata28_pmp_dp'][0]['param']['preprocessing_pipeline']):
    print '\t' + rebuild_func(dc) + '\\' # à affiner
# Out:
# df\
# 	.pipe(add_unix_time)\
# 	.pipe(partial(order_by_list,column_name=[u'aircraft', u'registration', u'departure_date', u'flight_leg_count', u'time']))\
# 	.pipe(partial(flight_duration,partition_by=[u'aircraft', u'registration', u'departure_date', u'flight_leg_count']))\
# 	.pipe(partial(add_flight_chrono,return_name=_unix_time_from_start,partition_by=[u'aircraft', u'registration', u'departure_date', u'flight_leg_count']))\
# 	.pipe(partial(filter_on_column,condition=>3600,column_name=flight_duration))\
# 	.pipe(partial(add_column_operation,operation=* 0.1,return_name=start_progno_unix_time,column_name=flight_duration))\
# 	.pipe(partial(add_column_operation,operation=* 0.9,return_name=end_progno_unix_time,column_name=flight_duration))\
# 	.pipe(partial(add_column_operation_2_cols,operation=>=,return_name=filter_start_progno_unix_time,column_name_1=_unix_time_from_start,column_name_2=start_progno_unix_time))\
# 	.pipe(partial(add_column_operation_2_cols,operation=<=,return_name=filter_end_progno_unix_time,column_name_1=_unix_time_from_start,column_name_2=end_progno_unix_time))\
# 	.pipe(partial(add_column_operation_2_cols,operation=&,return_name=filter_common,column_name_1=filter_start_progno_unix_time,column_name_2=filter_end_progno_unix_time))\
# 	.pipe(partial(add_column_euclidean_quotient,return_name=unix_time_quot_300,divisor=300,column_name=unix_time))\
# 	.pipe(partial(noise_percentile,column_name_cond=filter_common,window_length_second=300,partition_by=[u'aircraft', u'registration', u'departure_date', u'flight_leg_count'],column_name_time=_unix_time_from_start,percentile=90,return_name=noise_90_CURM_5QA4,column_name=_CURM_5QA4_1.1))\
# 	.pipe(partial(noise_percentile,column_name_cond=filter_common,window_length_second=300,partition_by=[u'aircraft', u'registration', u'departure_date', u'flight_leg_count'],column_name_time=_unix_time_from_start,percentile=90,return_name=noise_90_CURM_5QA1,column_name=_CURM_5QA1_1.2))\
# 	.pipe(partial(rising_edges,threshold_value=0.2,column_name_cond=filter_common,window_length_second=300,partition_by=[u'aircraft', u'registration', u'departure_date', u'flight_leg_count'],column_name_time=_unix_time_from_start,variable_2=_CURM_5QA4_1.1,variable_1=_CURM_5QA1_1.2,return_name=rising_edges_5qa1,column_euclidian_quotient=unix_time_quot_300))\
# 	.pipe(partial(rising_edges,threshold_value=0.2,column_name_cond=filter_common,window_length_second=300,partition_by=[u'aircraft', u'registration', u'departure_date', u'flight_leg_count'],column_name_time=_unix_time_from_start,variable_2=_CURM_5QA1_1.2,variable_1=_CURM_5QA4_1.1,return_name=rising_edges_5qa4,column_euclidian_quotient=unix_time_quot_300))\
# 	.pipe(partial(add_true_if_first_occurence,return_name=first_occurence_300,partition_by=[u'aircraft', u'registration', u'departure_date', u'flight_leg_count', u'unix_time_quot_300']))\

# %%
def rebuild_func_agg(dct):
    return dct['function'] + '(' + ','.join([k + '=' + str(v) for k, v in dct['param'].items()]) + ')'

# %%
print 'df.groupBy(' + str(d[u'ata28_pmp_dp'][1]['param']['aggregation_level']) + ')'
print '\t' + '.agg(' + ','.join(rebuild_func_agg(x) for x in d[u'ata28_pmp_dp'][1]['param']['aggregate_functions_spark']) + ')'
# Out:
# df.groupBy([u'aircraft', u'registration', u'departure_date', u'flight_leg_count'])
# 	.agg(count_condition(result_name=risingEdgesNumber5qa1,variable=rising_edges_5qa1,condition_value=0,column_name_cond=first_occurence_300),count_condition(result_name=risingEdgesNumber5qa4,variable=rising_edges_5qa4,condition_value=0,column_name_cond=first_occurence_300),agg_min(result_name=noise5qa1,variable=noise_90_CURM_5QA1,column_name_cond=filter_common),agg_min(result_name=noise5qa4,variable=noise_90_CURM_5QA4,column_name_cond=filter_common),agg_max(result_name=maxRisingEdges5qa1,variable=rising_edges_5qa1,column_name_cond=filter_common),agg_max(result_name=maxRisingEdges5qa4,variable=rising_edges_5qa4,column_name_cond=filter_common))

# %% [markdown]
# Problème : \ en bout de ligne. Arguments à mettre entre quotes ? Comment ils font dans l'appli lors du parsing ?

# %% [markdown]
# ### List file size on local FS

# %%
def list_file_size_fs(dir_path, file_ext):
    if dir_path[-1]=='/':
        dir_path = dir_path[:-1]
    files = [dir_path + '/' + x for x in os.listdir(dir_path) if os.path.isfile(dir_path + '/' + x) and file_ext in x]
    files_size = [round(os.path.getsize(x)/(1024.0*1024.0),3) for x in files]
    return pd.DataFrame(data={'file' : files, 'size_MiB' : files_size})
