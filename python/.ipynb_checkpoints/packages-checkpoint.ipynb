# %% [markdown]
# # ```matplotlib```
#
# Pour une utilisation dans un notebook IPython, utiliser la *magic command* ```%matplotlib``` (voir [la documentation](https://ipython.readthedocs.io/en/stable/interactive/magics.html#magic-matplotlib)). Les *magics* sont des fonctionnalités proposées par le kernel IPython. Leur disponibilité dépend donc du kernel utilisé. Y faire appel passe par l'utilisation d'un élément syntaxique qui n'est pas utilisé par le langage attaché au kernel. En Python il s'agit du caractère ```%```.
#
# La commande ```%matplotlib [-l] [gui]``` permet de faire passer ```matplotlib``` en mode interactif en utilisant ```gui``` comme backend ```matplotlib```. Par défaut (commande ```%matplotlib```), le backend utilisé est ```TkAgg```. Plusieurs backends sont disponibles pour l'utilisateur. Pour les lister, utiliser la commande ```%matplotlib -l``` ou ```%matplotlib --list```. Un backend fréquemment utilisé est ```inline``` qui est activé via la commande ```%matplotlib inline```. Les propriétés du backend utilisé peuvent être ajustée à l'aide de la *magic command* ```%config``` qui permet d'accéder à la configuration de IPython.

# %%
import matplotlib as plt
import matplotlib.cm as cm
# %matplotlib inline

# %%
help(plt)
# Out:
# Help on package matplotlib:
#
# NAME
#     matplotlib - This is an object-oriented plotting library.
#
# FILE
#     /tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/__init__.py
#
# DESCRIPTION
#     A procedural interface is provided by the companion pyplot module,
#     which may be imported directly, e.g.::
#
#         import matplotlib.pyplot as plt
#
#     or using ipython::
#
#         ipython
#
#     at your terminal, followed by::
#
#         In [1]: %matplotlib
#         In [2]: import matplotlib.pyplot as plt
#
#     at the ipython shell prompt.
#
#     For the most part, direct use of the object-oriented library is
#     encouraged when programming; pyplot is primarily for working
#     interactively.  The
#     exceptions are the pyplot commands :func:`~matplotlib.pyplot.figure`,
#     :func:`~matplotlib.pyplot.subplot`,
#     :func:`~matplotlib.pyplot.subplots`, and
#     :func:`~pyplot.savefig`, which can greatly simplify scripting.
#
#     Modules include:
#
#         :mod:`matplotlib.axes`
#             defines the :class:`~matplotlib.axes.Axes` class.  Most pylab
#             commands are wrappers for :class:`~matplotlib.axes.Axes`
#             methods.  The axes module is the highest level of OO access to
#             the library.
#
#         :mod:`matplotlib.figure`
#             defines the :class:`~matplotlib.figure.Figure` class.
#
#         :mod:`matplotlib.artist`
#             defines the :class:`~matplotlib.artist.Artist` base class for
#             all classes that draw things.
#
#         :mod:`matplotlib.lines`
#             defines the :class:`~matplotlib.lines.Line2D` class for
#             drawing lines and markers
#
#         :mod:`matplotlib.patches`
#             defines classes for drawing polygons
#
#         :mod:`matplotlib.text`
#             defines the :class:`~matplotlib.text.Text`,
#             :class:`~matplotlib.text.TextWithDash`, and
#             :class:`~matplotlib.text.Annotate` classes
#
#         :mod:`matplotlib.image`
#             defines the :class:`~matplotlib.image.AxesImage` and
#             :class:`~matplotlib.image.FigureImage` classes
#
#         :mod:`matplotlib.collections`
#             classes for efficient drawing of groups of lines or polygons
#
#         :mod:`matplotlib.colors`
#             classes for interpreting color specifications and for making
#             colormaps
#
#         :mod:`matplotlib.cm`
#             colormaps and the :class:`~matplotlib.image.ScalarMappable`
#             mixin class for providing color mapping functionality to other
#             classes
#
#         :mod:`matplotlib.ticker`
#             classes for calculating tick mark locations and for formatting
#             tick labels
#
#         :mod:`matplotlib.backends`
#             a subpackage with modules for various gui libraries and output
#             formats
#
#     The base matplotlib namespace includes:
#
#         :data:`~matplotlib.rcParams`
#             a global dictionary of default configuration settings.  It is
#             initialized by code which may be overridded by a matplotlibrc
#             file.
#
#         :func:`~matplotlib.rc`
#             a function for setting groups of rcParams values
#
#         :func:`~matplotlib.use`
#             a function for setting the matplotlib backend.  If used, this
#             function must be called immediately after importing matplotlib
#             for the first time.  In particular, it must be called
#             **before** importing pylab (if pylab is imported).
#
#     matplotlib was initially written by John D. Hunter (1968-2012) and is now
#     developed and maintained by a host of others.
#
#     Occasionally the internal documentation (python docstrings) will refer
#     to MATLAB&reg;, a registered trademark of The MathWorks, Inc.
#
# PACKAGE CONTENTS
#     _cm
#     _cntr
#     _delaunay
#     _image
#     _mathtext_data
#     _path
#     _png
#     _pylab_helpers
#     _qhull
#     _tri
#     afm
#     animation
#     artist
#     axes (package)
#     axis
#     backend_bases
#     backends (package)
#     bezier
#     blocking_input
#     cbook
#     cm
#     collections
#     colorbar
#     colors
#     compat (package)
#     container
#     contour
#     dates
#     delaunay (package)
#     docstring
#     dviread
#     figure
#     finance
#     font_manager
#     fontconfig_pattern
#     ft2font
#     gridspec
#     hatch
#     image
#     legend
#     legend_handler
#     lines
#     markers
#     mathtext
#     mlab
#     mpl
#     offsetbox
#     patches
#     path
#     patheffects
#     projections (package)
#     pylab
#     pyplot
#     quiver
#     rcsetup
#     sankey
#     scale
#     sphinxext (package)
#     spines
#     stackplot
#     streamplot
#     style (package)
#     table
#     testing (package)
#     tests (package)
#     texmanager
#     text
#     textpath
#     ticker
#     tight_bbox
#     tight_layout
#     transforms
#     tri (package)
#     ttconv
#     type1font
#     units
#     widgets
#
# SUBMODULES
#     subprocess
#
# CLASSES
#     __builtin__.dict(__builtin__.object)
#         RcParams
#     __builtin__.object
#         rc_context
#     Verbose
#
#     class RcParams(__builtin__.dict)
#      |  A dictionary object including validation
#      |
#      |  validating functions are defined and associated with rc parameters in
#      |  :mod:`matplotlib.rcsetup`
#      |
#      |  Method resolution order:
#      |      RcParams
#      |      __builtin__.dict
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __getitem__(self, key)
#      |
#      |  __init__(self, *args, **kwargs)
#      |      # validate values on the way in
#      |
#      |  __repr__(self)
#      |
#      |  __setitem__(self, key, val)
#      |
#      |  __str__(self)
#      |
#      |  find_all(self, pattern)
#      |      Return the subset of this RcParams dictionary whose keys match,
#      |      using :func:`re.search`, the given ``pattern``.
#      |
#      |      .. note::
#      |
#      |          Changes to the returned dictionary are *not* propagated to
#      |          the parent RcParams dictionary.
#      |
#      |  keys(self)
#      |      Return sorted list of keys.
#      |
#      |  update(self, *args, **kwargs)
#      |      # http://stackoverflow.com/questions/2390827/how-to-properly-subclass-dict-and-override-get-set
#      |      # the default dict `update` does not use __setitem__
#      |      # so rcParams.update(...) (such as in seaborn) side-steps
#      |      # all of the validation over-ride update to force
#      |      # through __setitem__
#      |
#      |  values(self)
#      |      Return values in order of sorted keys.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  msg_depr = u'%s is deprecated and replaced with %s; please use the lat...
#      |
#      |  msg_depr_ignore = u'%s is deprecated and ignored. Use %s'
#      |
#      |  validate = {u'agg.path.chunksize': <function validate_int>, u'animatio...
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from __builtin__.dict:
#      |
#      |  __cmp__(...)
#      |      x.__cmp__(y) <==> cmp(x,y)
#      |
#      |  __contains__(...)
#      |      D.__contains__(k) -> True if D has a key k, else False
#      |
#      |  __delitem__(...)
#      |      x.__delitem__(y) <==> del x[y]
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __iter__(...)
#      |      x.__iter__() <==> iter(x)
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __len__(...)
#      |      x.__len__() <==> len(x)
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  __sizeof__(...)
#      |      D.__sizeof__() -> size of D in memory, in bytes
#      |
#      |  clear(...)
#      |      D.clear() -> None.  Remove all items from D.
#      |
#      |  copy(...)
#      |      D.copy() -> a shallow copy of D
#      |
#      |  fromkeys(...)
#      |      dict.fromkeys(S[,v]) -> New dict with keys from S and values equal to v.
#      |      v defaults to None.
#      |
#      |  get(...)
#      |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#      |
#      |  has_key(...)
#      |      D.has_key(k) -> True if D has a key k, else False
#      |
#      |  items(...)
#      |      D.items() -> list of D's (key, value) pairs, as 2-tuples
#      |
#      |  iteritems(...)
#      |      D.iteritems() -> an iterator over the (key, value) items of D
#      |
#      |  iterkeys(...)
#      |      D.iterkeys() -> an iterator over the keys of D
#      |
#      |  itervalues(...)
#      |      D.itervalues() -> an iterator over the values of D
#      |
#      |  pop(...)
#      |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#      |      If key is not found, d is returned if given, otherwise KeyError is raised
#      |
#      |  popitem(...)
#      |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#      |      2-tuple; but raise KeyError if D is empty.
#      |
#      |  setdefault(...)
#      |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#      |
#      |  viewitems(...)
#      |      D.viewitems() -> a set-like object providing a view on D's items
#      |
#      |  viewkeys(...)
#      |      D.viewkeys() -> a set-like object providing a view on D's keys
#      |
#      |  viewvalues(...)
#      |      D.viewvalues() -> an object providing a view on D's values
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from __builtin__.dict:
#      |
#      |  __hash__ = None
#      |
#      |  __new__ = <built-in method __new__ of type object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#
#     class Verbose
#      |  A class to handle reporting.  Set the fileo attribute to any file
#      |  instance to handle the output.  Default is sys.stdout
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self)
#      |
#      |  ge(self, level)
#      |      return true if self.level is >= level
#      |
#      |  report(self, s, level=u'helpful')
#      |      print message s to self.fileo if self.level>=level.  Return
#      |      value indicates whether a message was issued
#      |
#      |  set_fileo(self, fname)
#      |
#      |  set_level(self, level)
#      |      set the verbosity to one of the Verbose.levels strings
#      |
#      |  wrap(self, fmt, func, level=u'helpful', always=True)
#      |      return a callable function that wraps func and reports it
#      |      output through the verbose handler if current verbosity level
#      |      is higher than level
#      |
#      |      if always is True, the report will occur on every function
#      |      call; otherwise only on the first time the function is called
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  arg = '/home/secunix/at053351/.local/share/jupyter/runtime/kernel-4d70...
#      |
#      |  i = 3
#      |
#      |  level = u'debug-annoying'
#      |
#      |  levels = (u'silent', u'helpful', u'debug', u'debug-annoying')
#      |
#      |  vald = {u'debug': 2, u'debug-annoying': 3, u'helpful': 1, u'silent': 0...
#
#     class rc_context(__builtin__.object)
#      |  Return a context manager for managing rc settings.
#      |
#      |  This allows one to do::
#      |
#      |      with mpl.rc_context(fname='screen.rc'):
#      |          plt.plot(x, a)
#      |          with mpl.rc_context(fname='print.rc'):
#      |              plt.plot(x, b)
#      |          plt.plot(x, c)
#      |
#      |  The 'a' vs 'x' and 'c' vs 'x' plots would have settings from
#      |  'screen.rc', while the 'b' vs 'x' plot would have settings from
#      |  'print.rc'.
#      |
#      |  A dictionary can also be passed to the context manager::
#      |
#      |      with mpl.rc_context(rc={'text.usetex': True}, fname='screen.rc'):
#      |          plt.plot(x, a)
#      |
#      |  The 'rc' dictionary takes precedence over the settings loaded from
#      |  'fname'.  Passing a dictionary only is also valid.
#      |
#      |  Methods defined here:
#      |
#      |  __enter__(self)
#      |
#      |  __exit__(self, type, value, tb)
#      |
#      |  __init__(self, rc=None, fname=None)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# FUNCTIONS
#     checkdep_dvipng()
#
#     checkdep_ghostscript()
#
#     checkdep_inkscape()
#
#     checkdep_pdftops()
#
#     checkdep_ps_distiller(s)
#
#     checkdep_tex()
#
#     checkdep_usetex(s)
#
#     checkdep_xmllint()
#
#     compare_versions(a, b)
#         return True if a is greater than or equal to b
#
#     get_backend()
#         Return the name of the current backend.
#
#     get_cachedir = wrapper(*args, **kwargs)
#         Return the location of the cache directory.
#
#         The procedure used to find the directory is the same as for
#         _get_config_dir, except using `$XDG_CACHE_HOME`/`~/.cache` instead.
#
#     get_configdir = wrapper(*args, **kwargs)
#         Return the string representing the configuration directory.
#
#         The directory is chosen as follows:
#
#         1. If the MPLCONFIGDIR environment variable is supplied, choose that.
#
#         2a. On Linux, if `$HOME/.matplotlib` exists, choose that, but warn that
#             that is the old location.  Barring that, follow the XDG specification
#             and look first in `$XDG_CONFIG_HOME`, if defined, or `$HOME/.config`.
#
#         2b. On other platforms, choose `$HOME/.matplotlib`.
#
#         3. If the chosen directory exists and is writable, use that as the
#            configuration directory.
#         4. If possible, create a temporary directory, and use it as the
#            configuration directory.
#         5. A writable directory could not be found or created; return None.
#
#     get_data_path = wrapper(*args, **kwargs)
#
#     get_example_data(fname)
#         get_example_data is deprecated -- use matplotlib.cbook.get_sample_data instead
#
#     get_home = wrapper(*args, **kwargs)
#         Find user's home directory if possible.
#         Otherwise, returns None.
#
#         :see:  http://mail.python.org/pipermail/python-list/2005-February/325395.html
#
#     get_py2exe_datafiles()
#
#     interactive(b)
#         Set interactive mode to boolean b.
#
#         If b is True, then draw after every plotting command, e.g., after xlabel
#
#     is_interactive()
#         Return true if plot mode is interactive
#
#     is_url(filename)
#         Return True if string is an http, ftp, or file URL path.
#
#     matplotlib_fname()
#         Get the location of the config file.
#
#         The file location is determined in the following order
#
#         - `$PWD/matplotlibrc`
#
#         - environment variable `MATPLOTLIBRC`
#
#         - `$MPLCONFIGDIR/matplotlib`
#
#         - On Linux,
#
#               - `$HOME/.matplotlib/matplotlibrc`, if it exists
#
#               - or `$XDG_CONFIG_HOME/matplotlib/matplotlibrc` (if
#                 $XDG_CONFIG_HOME is defined)
#
#               - or `$HOME/.config/matplotlib/matplotlibrc` (if
#                 $XDG_CONFIG_HOME is not defined)
#
#         - On other platforms,
#
#              - `$HOME/.matplotlib/matplotlibrc` if `$HOME` is defined.
#
#         - Lastly, it looks in `$MATPLOTLIBDATA/matplotlibrc` for a
#           system-defined copy.
#
#     rc(group, **kwargs)
#         Set the current rc params.  Group is the grouping for the rc, e.g.,
#         for ``lines.linewidth`` the group is ``lines``, for
#         ``axes.facecolor``, the group is ``axes``, and so on.  Group may
#         also be a list or tuple of group names, e.g., (*xtick*, *ytick*).
#         *kwargs* is a dictionary attribute name/value pairs, e.g.,::
#
#           rc('lines', linewidth=2, color='r')
#
#         sets the current rc params and is equivalent to::
#
#           rcParams['lines.linewidth'] = 2
#           rcParams['lines.color'] = 'r'
#
#         The following aliases are available to save typing for interactive
#         users:
#
#         =====   =================
#         Alias   Property
#         =====   =================
#         'lw'    'linewidth'
#         'ls'    'linestyle'
#         'c'     'color'
#         'fc'    'facecolor'
#         'ec'    'edgecolor'
#         'mew'   'markeredgewidth'
#         'aa'    'antialiased'
#         =====   =================
#
#         Thus you could abbreviate the above rc command as::
#
#               rc('lines', lw=2, c='r')
#
#
#         Note you can use python's kwargs dictionary facility to store
#         dictionaries of default parameters.  e.g., you can customize the
#         font rc as follows::
#
#           font = {'family' : 'monospace',
#                   'weight' : 'bold',
#                   'size'   : 'larger'}
#
#           rc('font', **font)  # pass in the font dict as kwargs
#
#         This enables you to easily switch between several configurations.
#         Use :func:`~matplotlib.pyplot.rcdefaults` to restore the default
#         rc params after changes.
#
#     rc_file(fname)
#         Update rc params from file.
#
#     rc_file_defaults()
#         Restore the default rc params from the original matplotlib rc that
#         was loaded
#
#     rc_params(fail_on_error=False)
#         Return a :class:`matplotlib.RcParams` instance from the
#         default matplotlib rc file.
#
#     rc_params_from_file(fname, fail_on_error=False, use_default_template=True)
#         Return :class:`matplotlib.RcParams` from the contents of the given file.
#
#         Parameters
#         ----------
#         fname : str
#             Name of file parsed for matplotlib settings.
#         fail_on_error : bool
#             If True, raise an error when the parser fails to convert a parameter.
#         use_default_template : bool
#             If True, initialize with default parameters before updating with those
#             in the given file. If False, the configuration class only contains the
#             parameters specified in the file. (Useful for updating dicts.)
#
#     rcdefaults()
#         Restore the default rc params.  These are not the params loaded by
#         the rc file, but mpl's internal params.  See rc_file_defaults for
#         reloading the default params from the rc file
#
#     test(verbosity=1)
#         run the matplotlib test suite
#
#     tk_window_focus()
#         Return true if focus maintenance under TkAgg on win32 is on.
#         This currently works only for python.exe and IPython.exe.
#         Both IDLE and Pythonwin.exe fail badly when tk_window_focus is on.
#
#     use(arg, warn=True, force=False)
#         Set the matplotlib backend to one of the known backends.
#
#         The argument is case-insensitive. *warn* specifies whether a
#         warning should be issued if a backend has already been set up.
#         *force* is an **experimental** flag that tells matplotlib to
#         attempt to initialize a new backend by reloading the backend
#         module.
#
#         .. note::
#
#             This function must be called *before* importing pyplot for
#             the first time; or, if you are not using pyplot, it must be called
#             before importing matplotlib.backends.  If warn is True, a warning
#             is issued if you try and call this after pylab or pyplot have been
#             loaded.  In certain black magic use cases, e.g.
#             :func:`pyplot.switch_backend`, we are doing the reloading necessary to
#             make the backend switch work (in some cases, e.g., pure image
#             backends) so one can set warn=False to suppress the warnings.
#
#         To find out which backend is currently set, see
#         :func:`matplotlib.get_backend`.
#
# DATA
#     URL_REGEX = <_sre.SRE_Pattern object>
#     __version__ = '1.4.3'
#     __version__numpy__ = '1.6'
#     absolute_import = _Feature((2, 5, 0, 'alpha', 1), (3, 0, 0, 'alpha', 0...
#     bad_pyparsing = False
#     default = True
#     defaultParams = {u'agg.path.chunksize': [0, <function validate_int>], ...
#     default_test_modules = [u'matplotlib.tests.test_agg', u'matplotlib.tes...
#     division = _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 8192...
#     f = Forward: "a"
#     key = u'svg.embed_char_paths'
#     major = 2
#     minor1 = 7
#     minor2 = 11
#     print_function = _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0)...
#     rcParams = RcParams({u'agg.path.chunksize': 0,
#               u'...size': 2...
#     rcParamsDefault = RcParams({u'agg.path.chunksize': 0,
#               u'...s...
#     rcParamsOrig = {u'agg.path.chunksize': 0, u'animation.avconv_args': []...
#     s = '/home/secunix/at053351/.local/share/jupyter/runtime/kernel-4d70ea...
#     tmp = 0
#     unicode_literals = _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', ...
#     verbose = <matplotlib.Verbose instance>
#
# VERSION
#     1.4.3

# %%
import types
isinstance('register_cmap', types.FunctionType)
# Out:
# False

# %%
for a in dir(cm):
    if isinstance(getattr(cm, a), types.FunctionType):
        print getattr(cm, a).__name__
# Out:
# _generate_cmap
# _reverse_cmap_spec
# _reverser
# get_cmap
# register_cmap
# revcmap

# %%
for a in dir(cm):
    if isinstance(getattr(cm, a), types.ClassType):
        print a + "   " + str(type(getattr(cm, a)))
# Out:
# ScalarMappable   <type 'classobj'>

# %%
print len(dir(plt))
len(plt.__dict__.keys())
# Out:
# 163
# 163

# %%
for obj in plt.__dict__.values():
    if type(obj) is types.ModuleType: 
        print obj.__name__
        
# Les submodules sont les sous-répertoires du répertoire du package
# https://dzone.com/articles/listing-a-directory-with-python cf. os.walk pour explorer récursivement le package
# Il semble que dict liste aussi les dépendances 
# On peut s'assurer qu'on a affaire à un submodule avec la présence de __init__
# Out:
# matplotlib.text
# matplotlib.pylab
# matplotlib.compat.subprocess
# matplotlib.colors
# matplotlib.bezier
# matplotlib._qhull
# pyparsing
# matplotlib.style
# distutils
# tempfile
# matplotlib.collections
# matplotlib.legend_handler
# matplotlib.units
# matplotlib._cm
# matplotlib.finance
# matplotlib.ticker
# matplotlib.tri
# matplotlib.cbook
# matplotlib.artist
# matplotlib.textpath
# matplotlib.transforms
# matplotlib.projections
# matplotlib.contour
# matplotlib.compat
# matplotlib.font_manager
# matplotlib.container
# matplotlib.pyplot
# matplotlib.axes
# matplotlib.markers
# matplotlib.streamplot
# re
# matplotlib.stackplot
# matplotlib._pylab_helpers
# matplotlib.docstring
# matplotlib.mathtext
# matplotlib.table
# matplotlib.legend
# matplotlib.tight_bbox
# matplotlib.dates
# matplotlib.fontconfig_pattern
# matplotlib._cntr
# matplotlib._mathtext_data
# matplotlib._tri
# matplotlib.ft2font
# os
# matplotlib.cm
# matplotlib.image
# matplotlib.path
# matplotlib._image
# matplotlib.backends
# matplotlib.widgets
# numpy
# matplotlib.gridspec
# matplotlib._png
# matplotlib.patches
# matplotlib.offsetbox
# matplotlib.blocking_input
# matplotlib.colorbar
# matplotlib.quiver
# matplotlib.figure
# matplotlib.texmanager
# contextlib
# matplotlib.axis
# matplotlib.afm
# matplotlib.mlab
# matplotlib.backend_bases
# matplotlib.rcsetup
# six
# matplotlib.spines
# dateutil
# warnings
# sys
# matplotlib.scale
# matplotlib.lines
# matplotlib.dviread
# matplotlib._path

# %%
import os
print os.path.dirname(plt.__file__)
print os.path.abspath(plt.__file__)
# Out:
# /tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib
# /tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/__init__.pyc

# %%
import sys
for pth in sys.path:
    print pth

# %%
for key, obj in plt.__dict__.iteritems():
    if type(obj) is types.ModuleType: 
        print key
# Out:
# text
# pylab
# subprocess
# colors
# bezier
# _qhull
# pyparsing
# style
# distutils
# tempfile
# collections
# legend_handler
# units
# _cm
# finance
# ticker
# tri
# cbook
# artist
# textpath
# transforms
# projections
# contour
# compat
# font_manager
# container
# pyplot
# axes
# markers
# streamplot
# re
# stackplot
# _pylab_helpers
# docstring
# mathtext
# table
# legend
# tight_bbox
# dates
# fontconfig_pattern
# _cntr
# _mathtext_data
# _tri
# ft2font
# os
# cm
# image
# path
# _image
# backends
# widgets
# numpy
# gridspec
# _png
# patches
# offsetbox
# blocking_input
# colorbar
# quiver
# figure
# texmanager
# contextlib
# axis
# afm
# mlab
# backend_bases
# rcsetup
# six
# spines
# dateutil
# warnings
# sys
# scale
# lines
# dviread
# _path

# %%
pk_dir = os.path.dirname(plt.__file__)
# os.listdir(pk_dir)
# is_dir is_file

gn = os.walk(pk_dir)

# %%
struct = []
for directory in os.walk(pk_dir): 
    py_files = [x for x in directory[2] if x.endswith('.py')]
    if len(py_files) == 0:
        continue
    else:
        is_submodule = ('__init__.py' in py_files)
        struct.append(tuple([directory[0], directory[1], py_files, is_submodule]))

# %%
subpk_items = [x for x in '/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/mpl-data/fonts/afm'.split('/') if x not in pk_dir.split('/')[:-1]]
'.'.join(subpk_items)
# Out:
# 'matplotlib.mpl-data.fonts.afm'

# %%
list(os.walk(pk_dir))
# Out:
# [('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib',
#   ['delaunay',
#    'axes',
#    'mpl-data',
#    'style',
#    'sphinxext',
#    'tri',
#    'backends',
#    'compat',
#    'testing',
#    'projections',
#    'tests'],
#   ['backend_bases.py',
#    'texmanager.pyc',
#    'cm.pyc',
#    'cbook.pyc',
#    'stackplot.pyc',
#    'collections.py',
#    'transforms.pyc',
#    'mathtext.py',
#    'mlab.py',
#    'patheffects.py',
#    'font_manager.pyc',
#    'type1font.py',
#    'artist.pyc',
#    'fontconfig_pattern.py',
#    'blocking_input.pyc',
#    'lines.pyc',
#    'axis.pyc',
#    '__init__.pyc',
#    'scale.pyc',
#    'widgets.py',
#    'pyplot.pyc',
#    'container.py',
#    'colorbar.py',
#    'backend_bases.pyc',
#    'dviread.pyc',
#    'markers.py',
#    'image.pyc',
#    'hatch.py',
#    '_cntr.so',
#    'dates.py',
#    'collections.pyc',
#    'widgets.pyc',
#    'artist.py',
#    'table.py',
#    '_cm.py',
#    'afm.py',
#    'ticker.py',
#    'colorbar.pyc',
#    'path.pyc',
#    'figure.py',
#    'streamplot.pyc',
#    'bezier.py',
#    'markers.pyc',
#    'ttconv.so',
#    'tight_layout.pyc',
#    'legend_handler.py',
#    'legend_handler.pyc',
#    'colors.py',
#    'spines.py',
#    '_pylab_helpers.pyc',
#    'quiver.py',
#    'sankey.pyc',
#    'offsetbox.py',
#    'animation.pyc',
#    '__init__.py',
#    '_tri.so',
#    'tight_bbox.py',
#    '_png.so',
#    'patches.py',
#    'bezier.pyc',
#    'streamplot.py',
#    'cbook.py',
#    '_delaunay.so',
#    '_image.so',
#    'mathtext.pyc',
#    'docstring.pyc',
#    'ft2font.so',
#    'figure.pyc',
#    'pylab.pyc',
#    '_pylab_helpers.py',
#    'afm.pyc',
#    'mpl.pyc',
#    'container.pyc',
#    'texmanager.py',
#    'blocking_input.py',
#    'contour.pyc',
#    'axis.py',
#    'lines.py',
#    'tight_layout.py',
#    'contour.py',
#    'rcsetup.py',
#    'transforms.py',
#    'type1font.pyc',
#    'patheffects.pyc',
#    'tight_bbox.pyc',
#    '_cm.pyc',
#    'pyplot.py',
#    '_mathtext_data.pyc',
#    'ticker.pyc',
#    'spines.pyc',
#    '_qhull.so',
#    'dviread.py',
#    'legend.py',
#    'text.pyc',
#    'pylab.py',
#    'dates.pyc',
#    'units.pyc',
#    'docstring.py',
#    'cm.py',
#    'units.py',
#    'font_manager.py',
#    'quiver.pyc',
#    'image.py',
#    '_path.so',
#    'mpl.py',
#    'stackplot.py',
#    'legend.pyc',
#    'text.py',
#    'textpath.py',
#    'gridspec.pyc',
#    'scale.py',
#    'table.pyc',
#    'gridspec.py',
#    'hatch.pyc',
#    '_mathtext_data.py',
#    'textpath.pyc',
#    'rcsetup.pyc',
#    'finance.py',
#    'fontconfig_pattern.pyc',
#    'sankey.py',
#    'finance.pyc',
#    'colors.pyc',
#    'patches.pyc',
#    'mlab.pyc',
#    'path.py',
#    'offsetbox.pyc',
#    'animation.py']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/delaunay',
#   [],
#   ['interpolate.py',
#    '__init__.pyc',
#    'testfuncs.pyc',
#    '__init__.py',
#    'triangulate.pyc',
#    'triangulate.py',
#    'interpolate.pyc',
#    'testfuncs.py']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/axes',
#   [],
#   ['__init__.pyc',
#    '__init__.py',
#    '_subplots.py',
#    '_base.py',
#    '_subplots.pyc',
#    '_axes.py',
#    '_axes.pyc',
#    '_base.pyc']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/mpl-data',
#   ['fonts', 'stylelib', 'images', 'sample_data'],
#   ['matplotlibrc']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/mpl-data/fonts',
#   ['afm', 'ttf', 'pdfcorefonts'],
#   []),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/mpl-data/fonts/afm',
#   [],
#   ['cmr10.afm',
#    'phvb8an.afm',
#    'putb8a.afm',
#    'pagk8a.afm',
#    'cmex10.afm',
#    'phvbo8a.afm',
#    'phvlo8a.afm',
#    'pagdo8a.afm',
#    'pcrbo8a.afm',
#    'pncri8a.afm',
#    'putbi8a.afm',
#    'ptmb8a.afm',
#    'pplb8a.afm',
#    'pbkl8a.afm',
#    'pzdr.afm',
#    'psyr.afm',
#    'putr8a.afm',
#    'phvl8a.afm',
#    'pzcmi8a.afm',
#    'cmsy10.afm',
#    'phvb8a.afm',
#    'pplbi8a.afm',
#    'pbkli8a.afm',
#    'ptmbi8a.afm',
#    'pncb8a.afm',
#    'pbkd8a.afm',
#    'phvro8an.afm',
#    'cmmi10.afm',
#    'phvr8a.afm',
#    'pplr8a.afm',
#    'phvbo8an.afm',
#    'ptmr8a.afm',
#    'pcrr8a.afm',
#    'phvr8an.afm',
#    'pncbi8a.afm',
#    'pbkdi8a.afm',
#    'pcrb8a.afm',
#    'pcrro8a.afm',
#    'putri8a.afm',
#    'pplri8a.afm',
#    'cmtt10.afm',
#    'pagko8a.afm',
#    'pncr8a.afm',
#    'ptmri8a.afm',
#    'pagd8a.afm',
#    'phvro8a.afm']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/mpl-data/fonts/ttf',
#   [],
#   ['cmmi10.ttf',
#    'cmtt10.ttf',
#    'cmss10.ttf',
#    'STIXSizOneSymBol.ttf',
#    'STIXNonUniIta.ttf',
#    'COPYRIGHT.TXT',
#    'VeraMoBI.ttf',
#    'README.TXT',
#    'Vera.ttf',
#    'VeraBd.ttf',
#    'VeraBI.ttf',
#    'STIXNonUni.ttf',
#    'STIXGeneralItalic.ttf',
#    'STIXGeneralBolIta.ttf',
#    'VeraIt.ttf',
#    'STIXNonUniBolIta.ttf',
#    'cmex10.ttf',
#    'cmb10.ttf',
#    'LICENSE_STIX',
#    'STIXSizFiveSymReg.ttf',
#    'STIXGeneralBol.ttf',
#    'STIXNonUniBol.ttf',
#    'VeraMoIt.ttf',
#    'VeraMono.ttf',
#    'STIXSizTwoSymReg.ttf',
#    'VeraSeBd.ttf',
#    'STIXSizTwoSymBol.ttf',
#    'STIXSizFourSymReg.ttf',
#    'STIXSizFourSymBol.ttf',
#    'STIXGeneral.ttf',
#    'VeraSe.ttf',
#    'VeraMoBd.ttf',
#    'cmsy10.ttf',
#    'STIXSizThreeSymBol.ttf',
#    'STIXSizOneSymReg.ttf',
#    'cmr10.ttf',
#    'STIXSizThreeSymReg.ttf',
#    'RELEASENOTES.TXT']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts',
#   [],
#   ['Helvetica.afm',
#    'Courier.afm',
#    'Courier-Oblique.afm',
#    'Helvetica-Bold.afm',
#    'Helvetica-Oblique.afm',
#    'Times-Roman.afm',
#    'Times-Bold.afm',
#    'Times-BoldItalic.afm',
#    'Helvetica-BoldOblique.afm',
#    'Courier-BoldOblique.afm',
#    'Courier-Bold.afm',
#    'Times-Italic.afm',
#    'Symbol.afm',
#    'readme.txt',
#    'ZapfDingbats.afm']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib',
#   [],
#   ['ggplot.mplstyle',
#    'dark_background.mplstyle',
#    'bmh.mplstyle',
#    'grayscale.mplstyle',
#    'fivethirtyeight.mplstyle']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/mpl-data/images',
#   [],
#   ['stock_right.xpm',
#    'move.png',
#    'stock_refresh.ppm',
#    'zoom_to_rect.svg',
#    'back.png',
#    'stock_close.ppm',
#    'stock_up.ppm',
#    'home.ppm',
#    'hand.svg',
#    'forward.xpm',
#    'stock_save_as.xpm',
#    'move.ppm',
#    'move.xpm',
#    'stock_zoom-in.ppm',
#    'stock_left.xpm',
#    'matplotlib.svg',
#    'stock_up.xpm',
#    'back.svg',
#    'hand.ppm',
#    'stock_close.xpm',
#    'filesave.svg',
#    'stock_zoom-out.xpm',
#    'stock_save_as.ppm',
#    'stock_refresh.xpm',
#    'zoom_to_rect.xpm',
#    'back.ppm',
#    'qt4_editor_options.svg',
#    'back.xpm',
#    'home.png',
#    'forward.ppm',
#    'hand.png',
#    'subplots.png',
#    'home.xpm',
#    'hand.xpm',
#    'matplotlib.png',
#    'filesave.ppm',
#    'home.svg',
#    'subplots.ppm',
#    'zoom_to_rect.ppm',
#    'stock_left.ppm',
#    'zoom_to_rect.png',
#    'stock_zoom-in.xpm',
#    'stock_down.ppm',
#    'stock_zoom-out.ppm',
#    'stock_down.xpm',
#    'qt4_editor_options.png',
#    'matplotlib.gif',
#    'subplots.xpm',
#    'move.svg',
#    'stock_right.ppm',
#    'forward.png',
#    'forward.svg',
#    'filesave.png',
#    'filesave.xpm']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/mpl-data/sample_data',
#   ['axes_grid'],
#   ['s1045.ima.gz',
#    'lena.png',
#    'embedding_in_wx3.xrc',
#    'logo2.png',
#    'eeg.dat',
#    'Minduka_Present_Blue_Pack.png',
#    'membrane.dat',
#    'demodata.csv',
#    'AAPL.dat.gz',
#    'INTC.dat.gz',
#    'lena.jpg',
#    'msft.csv',
#    'goog.npy',
#    'aapl.csv',
#    'ct.raw.gz',
#    'grace_hopper.png',
#    'aapl.npy.gz',
#    'grace_hopper.jpg',
#    'data_x_x2_x3.csv',
#    'None_vs_nearest-pdf.png',
#    'necked_tensile_specimen.png',
#    'ada.png',
#    'README.txt']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/mpl-data/sample_data/axes_grid',
#   [],
#   ['bivariate_normal.npy']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/style',
#   [],
#   ['core.py', '__init__.pyc', '__init__.py', 'core.pyc']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/sphinxext',
#   [],
#   ['__init__.pyc',
#    'only_directives.py',
#    'mathmpl.pyc',
#    'ipython_directive.py',
#    'ipython_directive.pyc',
#    '__init__.py',
#    'mathmpl.py',
#    'only_directives.pyc',
#    'plot_directive.py',
#    'plot_directive.pyc',
#    'ipython_console_highlighting.py',
#    'ipython_console_highlighting.pyc']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tri',
#   [],
#   ['tripcolor.pyc',
#    '__init__.pyc',
#    'triangulation.pyc',
#    'trirefine.py',
#    'trirefine.pyc',
#    'trifinder.py',
#    'triangulation.py',
#    'triplot.pyc',
#    'triplot.py',
#    '__init__.py',
#    'tripcolor.py',
#    'tritools.pyc',
#    'tricontour.py',
#    'tritools.py',
#    'triinterpolate.pyc',
#    'trifinder.pyc',
#    'triinterpolate.py',
#    'tricontour.pyc']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/backends',
#   ['qt_editor', 'web_backend', 'Matplotlib.nib'],
#   ['backend_nbagg.py',
#    'backend_qt5.pyc',
#    'backend_wxagg.pyc',
#    'backend_ps.py',
#    'backend_macosx.pyc',
#    'tkagg.py',
#    'backend_qt4.pyc',
#    'qt_compat.pyc',
#    'backend_qt5.py',
#    '__init__.pyc',
#    'backend_gtk3agg.pyc',
#    'backend_pdf.pyc',
#    'backend_gtkagg.py',
#    'backend_qt4agg.py',
#    'backend_mixed.py',
#    'backend_ps.pyc',
#    'backend_qt5agg.pyc',
#    'backend_agg.pyc',
#    'backend_macosx.py',
#    'backend_cairo.pyc',
#    'backend_wx.pyc',
#    'backend_tkagg.pyc',
#    'backend_gtk3cairo.py',
#    'backend_agg.py',
#    'backend_webagg.py',
#    'backend_gtkcairo.py',
#    '__init__.py',
#    'backend_gtkagg.pyc',
#    'backend_svg.py',
#    'backend_cairo.py',
#    'backend_gtk3.pyc',
#    'backend_qt4.py',
#    'backend_mixed.pyc',
#    'backend_pgf.pyc',
#    'backend_webagg_core.pyc',
#    'backend_gtk3cairo.pyc',
#    'backend_wx.py',
#    'backend_gtk3agg.py',
#    'qt_compat.py',
#    'backend_webagg.pyc',
#    'backend_template.py',
#    'qt4_compat.pyc',
#    'backend_gdk.py',
#    'backend_qt5agg.py',
#    'backend_cocoaagg.py',
#    'backend_nbagg.pyc',
#    'windowing.py',
#    'backend_gtk3.py',
#    'backend_pdf.py',
#    'backend_gtk.pyc',
#    'backend_tkagg.py',
#    'backend_gtk.py',
#    'backend_template.pyc',
#    'backend_svg.pyc',
#    'backend_gtkcairo.pyc',
#    '_backend_agg.so',
#    'backend_wxagg.py',
#    'backend_gdk.pyc',
#    'backend_pgf.py',
#    'backend_webagg_core.py',
#    'backend_cocoaagg.pyc',
#    'windowing.pyc',
#    'qt4_compat.py',
#    '_tkagg.so',
#    'tkagg.pyc',
#    'backend_qt4agg.pyc']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/backends/qt_editor',
#   [],
#   ['__init__.pyc',
#    'figureoptions.py',
#    'formsubplottool.py',
#    '__init__.py',
#    'figureoptions.pyc',
#    'formlayout.py',
#    'formsubplottool.pyc',
#    'formlayout.pyc']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/backends/web_backend',
#   ['jquery', 'css'],
#   ['mpl.js',
#    'ipython_inline_figure.html',
#    'nbagg_uat.ipynb',
#    'all_figures.html',
#    'single_figure.html',
#    'nbagg_mpl.js',
#    'mpl_tornado.js']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/backends/web_backend/jquery',
#   ['js', 'css'],
#   []),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/backends/web_backend/jquery/js',
#   [],
#   ['jquery-ui.min.js', 'jquery.autogrow.js', 'jquery-1.7.1.min.js']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/backends/web_backend/jquery/css',
#   ['themes'],
#   []),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/backends/web_backend/jquery/css/themes',
#   ['base'],
#   []),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base',
#   ['images'],
#   ['jquery-ui.min.css']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/backends/web_backend/jquery/css/themes/base/images',
#   [],
#   ['ui-bg_highlight-soft_75_cccccc_1x100.png',
#    'ui-bg_glass_55_fbf9ee_1x400.png',
#    'ui-bg_glass_75_e6e6e6_1x400.png',
#    'ui-bg_flat_0_aaaaaa_40x100.png',
#    'ui-bg_flat_75_ffffff_40x100.png',
#    'ui-bg_glass_75_dadada_1x400.png',
#    'ui-bg_glass_65_ffffff_1x400.png',
#    'ui-icons_454545_256x240.png',
#    'ui-icons_cd0a0a_256x240.png',
#    'ui-bg_glass_95_fef1ec_1x400.png',
#    'ui-icons_222222_256x240.png',
#    'ui-icons_2e83ff_256x240.png',
#    'ui-icons_888888_256x240.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/backends/web_backend/css',
#   [],
#   ['page.css', 'boilerplate.css', 'fbm.css']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/backends/Matplotlib.nib',
#   [],
#   ['keyedobjects.nib', 'classes.nib', 'info.nib']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/compat',
#   [],
#   ['__init__.pyc', '__init__.py', 'subprocess.pyc', 'subprocess.py']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/testing',
#   ['jpl_units'],
#   ['compare.py',
#    '__init__.pyc',
#    'noseclasses.pyc',
#    'image_util.pyc',
#    'decorators.py',
#    '__init__.py',
#    'decorators.pyc',
#    'image_util.py',
#    'noseclasses.py',
#    'compare.pyc']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/testing/jpl_units',
#   [],
#   ['EpochConverter.pyc',
#    'StrConverter.py',
#    '__init__.pyc',
#    'UnitDblConverter.pyc',
#    'Epoch.pyc',
#    'EpochConverter.py',
#    'UnitDblFormatter.pyc',
#    'Duration.pyc',
#    '__init__.py',
#    'UnitDbl.py',
#    'Epoch.py',
#    'StrConverter.pyc',
#    'UnitDbl.pyc',
#    'Duration.py',
#    'UnitDblFormatter.py',
#    'UnitDblConverter.py']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/projections',
#   [],
#   ['__init__.pyc',
#    'geo.pyc',
#    '__init__.py',
#    'geo.py',
#    'polar.py',
#    'polar.pyc']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests',
#   ['baseline_images'],
#   ['test_streamplot.pyc',
#    'test_patheffects.py',
#    'test_font_manager.pyc',
#    'test_backend_bases.pyc',
#    'test_quiver.pyc',
#    'test_transforms.pyc',
#    'test_patches.py',
#    'test_colorbar.py',
#    'test_coding_standards.pyc',
#    'test_contour.pyc',
#    'test_mlab.pyc',
#    'test_delaunay.pyc',
#    '__init__.pyc',
#    'test_colors.py',
#    'test_gridspec.py',
#    'test_backend_qt4.pyc',
#    'test_backend_ps.pyc',
#    'test_ttconv.pyc',
#    'test_tightlayout.py',
#    'test_rcparams.pyc',
#    'test_legend.py',
#    'test_agg.py',
#    'test_figure.py',
#    'test_bbox_tight.py',
#    'test_quiver.py',
#    'test_skew.pyc',
#    'test_dates.py',
#    'test_backend_qt4.py',
#    'test_rcparams.rc',
#    'test_path.pyc',
#    'test_patheffects.pyc',
#    'test_basic.pyc',
#    'test_collections.py',
#    'test_sankey.py',
#    'test_axes.py',
#    'test_compare_images.py',
#    'test_text.py',
#    'test_backend_pdf.pyc',
#    'test_animation.py',
#    'test_png.pyc',
#    'test_subplots.pyc',
#    'test_animation.pyc',
#    'test_bbox_tight.pyc',
#    'test_sankey.pyc',
#    'test_patches.pyc',
#    'mpltest.ttf',
#    'test_dates.pyc',
#    'test_subplots.py',
#    'test_scale.pyc',
#    'test_legend.pyc',
#    'test_backend_pdf.py',
#    'test_mlab.py',
#    '__init__.py',
#    'test_compare_images.pyc',
#    'test_text.pyc',
#    'test_basic.py',
#    'test_simplification.pyc',
#    'test_artist.py',
#    'test_spines.py',
#    'test_ttconv.py',
#    'test_backend_bases.py',
#    'test_artist.pyc',
#    'test_tightlayout.pyc',
#    'test_figure.pyc',
#    'test_cbook.pyc',
#    'test_backend_qt5.py',
#    'test_gridspec.pyc',
#    'test_font_manager.py',
#    'test_axes.pyc',
#    'test_style.pyc',
#    'test_dviread.pyc',
#    'test_table.py',
#    'test_spines.pyc',
#    'test_cbook.py',
#    'test_pickle.pyc',
#    'test_ticker.py',
#    'test_pickle.py',
#    'test_ticker.pyc',
#    'test_triangulation.pyc',
#    'test_arrow_patches.pyc',
#    'test_delaunay.py',
#    'test_dviread.py',
#    'test_style.py',
#    'test_backend_pgf.py',
#    'test_streamplot.py',
#    'test_arrow_patches.py',
#    'test_backend_qt5.pyc',
#    'test_lines.py',
#    'test_triangulation.py',
#    'test_contour.py',
#    'test_transforms.py',
#    'test_image.pyc',
#    'test_rcparams.py',
#    'test_backend_pgf.pyc',
#    'test_lines.pyc',
#    'test_backend_ps.py',
#    'test_coding_standards.py',
#    'test_colorbar.pyc',
#    'test_mathtext.pyc',
#    'test_agg.pyc',
#    'test_path.py',
#    'test_colors.pyc',
#    'test_backend_svg.pyc',
#    'test_image.py',
#    'test_collections.pyc',
#    'test_table.pyc',
#    'test_mathtext.py',
#    'test_backend_svg.py',
#    'test_png.py',
#    'test_simplification.py',
#    'test_skew.py',
#    'test_scale.py']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images',
#   ['test_patheffects',
#    'test_backend_pdf',
#    'test_ttconv',
#    'test_scale',
#    'test_backend_pgf',
#    'test_path',
#    'test_skew',
#    'test_patches',
#    'test_dates',
#    'test_legend',
#    'test_transforms',
#    'test_png',
#    'test_table',
#    'test_simplification',
#    'test_spines',
#    'test_triangulation',
#    'test_subplots',
#    'test_pickle',
#    'test_figure',
#    'dviread',
#    'test_quiver',
#    'test_lines',
#    'pngsuite',
#    'test_colorbar',
#    'test_streamplot',
#    'test_delaunay',
#    'test_backend_svg',
#    'test_arrow_patches',
#    'test_compare_images',
#    'test_text',
#    'test_colors',
#    'test_axes',
#    'test_tightlayout',
#    'test_collections',
#    'test_mathtext',
#    'test_image',
#    'test_contour',
#    'test_artist',
#    'test_bbox_tight'],
#   []),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_patheffects',
#   [],
#   ['patheffect1.svg',
#    'patheffect2.svg',
#    'patheffect3.png',
#    'collection.png',
#    'patheffect2.png',
#    'collection.svg',
#    'patheffect3.pdf',
#    'patheffect1.pdf',
#    'patheffect2.pdf',
#    'patheffect1.png',
#    'collection.pdf',
#    'patheffect3.svg']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_backend_pdf',
#   [],
#   ['pdf_use14corefonts.pdf']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_ttconv',
#   [],
#   ['truetype-conversion.pdf']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_scale',
#   [],
#   ['log_scales.png', 'log_scales.svg', 'log_scales.pdf']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_backend_pgf',
#   [],
#   ['pgf_rcupdate1.pdf',
#    'pgf_pdflatex.pdf',
#    'pgf_rcupdate2.pdf',
#    'pgf_mixedmode.pdf',
#    'pgf_bbox_inches.pdf',
#    'pgf_xelatex.pdf']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_path',
#   [],
#   ['path_clipping.svg']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_skew',
#   [],
#   ['skew_rects.png',
#    'skew_axes.pdf',
#    'skew_rects.svg',
#    'skew_axes.png',
#    'skew_rects.pdf',
#    'skew_axes.svg']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_patches',
#   [],
#   ['clip_to_bbox.svg',
#    'patch_alpha_coloring.png',
#    'wedge_range.pdf',
#    'patch_custom_linestyle.png',
#    'patch_alpha_override.svg',
#    'patch_alpha_override.pdf',
#    'patch_alpha_coloring.pdf',
#    'patch_custom_linestyle.svg',
#    'clip_to_bbox.pdf',
#    'wedge_range.svg',
#    'clip_to_bbox.png',
#    'wedge_range.png',
#    'patch_alpha_override.png',
#    'patch_custom_linestyle.pdf',
#    'patch_alpha_coloring.svg']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_dates',
#   [],
#   ['RRuleLocator_bounds.png',
#    'date_axvspan.png',
#    'DateFormatter_fractionalSeconds.png',
#    'date_axhline.png',
#    'date_inverted_limit.png',
#    'date_axvline.png',
#    'date_empty.png',
#    'date_axhspan.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_legend',
#   [],
#   ['scatter_rc3.png',
#    'rgba_alpha.png',
#    'legend_auto2.svg',
#    'legend_expand.svg',
#    'legend_auto3.pdf',
#    'legend_various_labels.png',
#    'legend_auto1.png',
#    'scatter_rc1.pdf',
#    'legend_various_labels.pdf',
#    'framealpha.svg',
#    'framealpha.pdf',
#    'legend_auto1.pdf',
#    'scatter_rc3.pdf',
#    'fancy.pdf',
#    'fancy.png',
#    'legend_auto3.svg',
#    'legend_auto3.png',
#    'legend_auto2.pdf',
#    'fancy.svg',
#    'scatter_rc1.png',
#    'scatter_rc3.svg',
#    'legend_auto1.svg',
#    'legend_auto2.png',
#    'legend_various_labels.svg',
#    'legend_expand.png',
#    'rcparam_alpha.png',
#    'scatter_rc1.svg',
#    'framealpha.png',
#    'legend_expand.pdf']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_transforms',
#   [],
#   ['pre_transform_data.png',
#    'pre_transform_data.pdf',
#    'pre_transform_data.svg']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_png',
#   [],
#   ['pngsuite.png', 'uint16.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_table',
#   [],
#   ['table_labels.png', 'table_zorder.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_simplification',
#   [],
#   ['simplify_curve.pdf',
#    'clipping_diamond.svg',
#    'clipping_with_nans.svg',
#    'clipping.png',
#    'simplify_curve.png',
#    'hatch_simplify.png',
#    'fft_peaks.pdf',
#    'clipper_edge.png',
#    'clipping_diamond.pdf',
#    'overflow.png',
#    'fft_peaks.png',
#    'fft_peaks.svg',
#    'clipping_diamond.png',
#    'clipping.pdf',
#    'overflow.svg',
#    'clipper_edge.pdf',
#    'clipping.svg',
#    'clipper_edge.svg',
#    'para_equal_perp.png',
#    'para_equal_perp.svg',
#    'overflow.pdf',
#    'para_equal_perp.pdf',
#    'simplify_curve.svg',
#    'clipping_with_nans.png',
#    'hatch_simplify.pdf',
#    'clipping_with_nans.pdf',
#    'hatch_simplify.svg']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_spines',
#   [],
#   ['spines_capstyle.svg',
#    'spines_capstyle.png',
#    'spines_data_positions.pdf',
#    'spines_data_positions.png',
#    'spines_data_positions.svg',
#    'spines_capstyle.pdf',
#    'spines_axes_positions.png',
#    'spines_axes_positions.pdf',
#    'spines_axes_positions.svg']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_triangulation',
#   [],
#   ['tri_smooth_gradient.png', 'tri_smooth_contouring.png', 'tripcolor1.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_subplots',
#   [],
#   ['subplots_offset_text.svg',
#    'subplots_offset_text.png',
#    'subplots_offset_text.pdf']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_pickle',
#   [],
#   ['multi_pickle.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_figure',
#   [],
#   ['figure_suptitle.svg',
#    'alpha_background.svg',
#    'figure_suptitle.png',
#    'figure_suptitle.pdf',
#    'figure_today.pdf',
#    'figure_today.svg',
#    'alpha_background.png',
#    'figure_today.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/dviread',
#   [],
#   ['test.map']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_quiver',
#   [],
#   ['quiver_single_test_image.png',
#    'quiver_with_key_test_image.png',
#    'quiver_animated_test_image.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_lines',
#   [],
#   ['line_collection_dashes.png',
#    'line_collection_dashes.svg',
#    'line_collection_dashes.pdf']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/pngsuite',
#   [],
#   ['basn0g02.png',
#    'basn3p08.png',
#    'basn3p01.png',
#    'basn0g01.png',
#    'basn0g08.png',
#    'basn0g16.png',
#    'basn6a16.png',
#    'basn3p02.png',
#    'basn3p04.png',
#    'basn2c16.png',
#    'basn4a16.png',
#    'basn0g04.png',
#    'basn2c08.png',
#    'basn6a08.png',
#    'basn4a08.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_colorbar',
#   [],
#   ['double_cbar.png',
#    'cbar_locationing.png',
#    'colorbar_single_scatter.png',
#    'cbar_sharing.png',
#    'colorbar_extensions_proportional.png',
#    'colorbar_extensions_shape_uniform.png',
#    'colorbar_extensions_shape_proportional.png',
#    'cbar_with_subplots_adjust.png',
#    'cbar_with_orientation.png',
#    'colorbar_extensions_uniform.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_streamplot',
#   [],
#   ['streamplot_masks_and_nans_test_image.pdf',
#    'streamplot_masks_and_nans_test_image.svg',
#    'streamplot_linewidth_test_image.png',
#    'streamplot_masks_and_nans_test_image.png',
#    'streamplot_colormap_test_image.png',
#    'streamplot_colormap_test_image.pdf',
#    'streamplot_linewidth_test_image.pdf',
#    'streamplot_linewidth_test_image.svg',
#    'streamplot_colormap_test_image.svg']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_delaunay',
#   [],
#   ['saddle-nn-con.png',
#    'steep-nn-img.png',
#    'exponential-ref-con.png',
#    'trig-ref-img.png',
#    'cosine_peak-ref-img.png',
#    'saddle-ref-img.png',
#    'gauss-lin-img.png',
#    'trig-nn-con.png',
#    'saddle-lin-img.png',
#    'cloverleaf-ref-con.png',
#    'cliff-lin-con.png',
#    'cloverleaf-nn-con.png',
#    'cliff-ref-con.png',
#    'gauss-nn-img.png',
#    'cliff-nn-img.png',
#    'cosine_peak-nn-img.png',
#    'cosine_peak-lin-con.png',
#    'steep-ref-img.png',
#    'delaunay-1d-interp.png',
#    'sphere-nn-img.png',
#    'cloverleaf-ref-img.png',
#    'exponential-lin-img.png',
#    'sphere-ref-img.png',
#    'cliff-lin-img.png',
#    'gauss-ref-img.png',
#    'gentle-ref-img.png',
#    'cosine_peak-nn-con.png',
#    'gauss-lin-con.png',
#    'saddle-lin-con.png',
#    'trig-ref-con.png',
#    'sphere-lin-img.png',
#    'gauss-nn-con.png',
#    'exponential-ref-img.png',
#    'cloverleaf-lin-img.png',
#    'trig-lin-con.png',
#    'gentle-nn-img.png',
#    'cliff-nn-con.png',
#    'sphere-ref-con.png',
#    'trig-lin-img.png',
#    'cosine_peak-ref-con.png',
#    'gauss-ref-con.png',
#    'sphere-nn-con.png',
#    'exponential-nn-img.png',
#    'cosine_peak-lin-img.png',
#    'sphere-lin-con.png',
#    'gentle-nn-con.png',
#    'saddle-ref-con.png',
#    'cliff-ref-img.png',
#    'exponential-lin-con.png',
#    'exponential-nn-con.png',
#    'steep-lin-con.png',
#    'steep-ref-con.png',
#    'steep-nn-con.png',
#    'steep-lin-img.png',
#    'cloverleaf-nn-img.png',
#    'gentle-lin-img.png',
#    'trig-nn-img.png',
#    'saddle-nn-img.png',
#    'gentle-ref-con.png',
#    'cloverleaf-lin-con.png',
#    'gentle-lin-con.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_backend_svg',
#   [],
#   ['noscale.svg', 'noscale.pdf', 'noscale.png', 'fill_black_with_alpha.svg']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_arrow_patches',
#   [],
#   ['fancyarrow_test_image.svg',
#    'fancyarrow_test_image.pdf',
#    'fancyarrow_test_image.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_compare_images',
#   [],
#   ['all127.png',
#    'all128.png',
#    'basn3p02-half-1px-offset.png',
#    'basn3p02-1px-offset.png',
#    'basn3p02.png',
#    'basn3p02-scrambled.png',
#    'basn3p02-minorchange.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_text',
#   [],
#   ['font_styles.svg',
#    'titles.svg',
#    'multiline.pdf',
#    'titles.png',
#    'text_alignment.pdf',
#    'text_alignment.svg',
#    'text_alignment.png',
#    'text_contains.png',
#    'multiline.png',
#    'titles.pdf',
#    'axes_titles.png',
#    'annotation_negative_coords.png',
#    'font_styles.png',
#    'font_styles.pdf',
#    'multiline.svg',
#    'text_bboxclip.svg',
#    'text_bboxclip.png',
#    'text_bboxclip.pdf',
#    'antialiased.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_colors',
#   [],
#   ['levels_and_colors.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_axes',
#   [],
#   ['bxp_withmean_custompoint.png',
#    'vline_hline_zorder.svg',
#    'polar_wrap_360.pdf',
#    'hist2d_transpose.pdf',
#    'bxp_withmean_point.png',
#    'symlog2.svg',
#    'hist2d.png',
#    'bxp_nobox.png',
#    'mixed_collection.pdf',
#    'boxplot.svg',
#    'polar_units_2.pdf',
#    'markevery_linear_scales_zoomed.png',
#    'hist_step_bottom.png',
#    'specgram_noise.png',
#    'arc_ellipse.pdf',
#    'symlog2.png',
#    'errorbar_limits.png',
#    'axvspan_epoch.pdf',
#    'stackplot_test_image.png',
#    'scatter.svg',
#    'bxp_customwhisker.png',
#    'pcolormesh.png',
#    'magnitude_spectrum_freqs_linear.png',
#    'violinplot_horiz_custompoints_10.png',
#    'boxplot.pdf',
#    'fill_between_interpolate.svg',
#    'polar_rmin.png',
#    'test_eventplot_defaults.png',
#    'hist_stacked_stepfilled_alpha.png',
#    'shaped_data.svg',
#    'violinplot_horiz_custompoints_200.png',
#    'formatter_ticker_001.png',
#    'step_linestyle.png',
#    'scatter.pdf',
#    'formatter_ticker_002.pdf',
#    'hist_steplog.png',
#    'bxp_custompositions.png',
#    'hist2d.pdf',
#    'bxp_customoutlier.png',
#    'errorbar_mixed.pdf',
#    'magnitude_spectrum_freqs_dB.png',
#    'formatter_ticker_004.svg',
#    'hist_stacked_bar.png',
#    'vline_hline_zorder.png',
#    'polar_theta_position.pdf',
#    'hexbin_extent.png',
#    'polar_theta_position.svg',
#    'bxp_custommedian.png',
#    'pcolormesh.pdf',
#    'psd_noise.png',
#    'contour_hatching.svg',
#    'polar_wrap_180.pdf',
#    'formatter_ticker_001.svg',
#    'imshow.pdf',
#    'polar_coords.pdf',
#    'bxp_with_ylabels.png',
#    'vline_hline_zorder.pdf',
#    'markevery_log_scales.svg',
#    'autoscale_tiny_range.png',
#    'offset_points.png',
#    'magnitude_spectrum_noise_dB.png',
#    'polar_rlabel_position.png',
#    'formatter_large_small.pdf',
#    'violinplot_horiz_showmeans.png',
#    'specgram_angle_noise.png',
#    'pie_linewidth_2.png',
#    'test_alpha.png',
#    'polar_rlabel_position.pdf',
#    'single_point.png',
#    'hist_offset.png',
#    'markevery.pdf',
#    'hist_stacked_weights.pdf',
#    'symlog2.pdf',
#    'single_date.pdf',
#    'twin_axis_locaters_formatters.png',
#    'bxp_with_xlabels.png',
#    'bxp_customcap.png',
#    'arc_ellipse.svg',
#    'markevery_polar.pdf',
#    'hist_log.png',
#    'formatter_ticker_003.svg',
#    'hist_offset.pdf',
#    'polycollection_joinstyle.png',
#    'canonical.pdf',
#    'hist2d.svg',
#    'bxp_precentilewhis.png',
#    'polar_wrap_180.png',
#    'hist_stacked_weights.svg',
#    'const_xy.pdf',
#    'canonical.svg',
#    'pcolormesh_datetime_axis.png',
#    'mixed_collection.png',
#    'hist_stacked_stepfilled.png',
#    'hist_stacked_bar.pdf',
#    'hist2d_transpose.svg',
#    'bxp_rangewhis.png',
#    'axvspan_epoch.png',
#    'hist_stacked_weights.png',
#    'stackplot_test_baseline.svg',
#    'markevery_linear_scales_zoomed.svg',
#    'shaped_data.pdf',
#    'violinplot_vert_custompoints_10.png',
#    'imshow.svg',
#    'imshow_clip.pdf',
#    'shaped_data.png',
#    'symlog.pdf',
#    'boxplot_autorange_whiskers.pdf',
#    'hist_stacked_normed.pdf',
#    'specgram_magnitude_freqs.png',
#    'hist_stacked_stepfilled_alpha.svg',
#    'imshow_clip.svg',
#    'polar_units.svg',
#    'formatter_ticker_002.png',
#    'log_scales.png',
#    'twin_spines_on_top.png',
#    'hist_stacked_stepfilled.pdf',
#    'scatter.png',
#    'stackplot_test_baseline.pdf',
#    'eventplot.png',
#    'polar_units_2.svg',
#    'specgram_phase_noise.png',
#    'fill_between_interpolate.pdf',
#    'markevery_polar.png',
#    'bxp_custombox.png',
#    'csd_freqs.png',
#    'formatter_ticker_001.pdf',
#    'axhspan_epoch.svg',
#    'units_strings.png',
#    'angle_spectrum_noise.png',
#    'errorbar_basic.svg',
#    'markevery_linear_scales.png',
#    'boxplot_autorange_whiskers.svg',
#    'fill_between_interpolate.png',
#    'csd_noise.png',
#    'twin_axis_locaters_formatters.pdf',
#    'hist_stacked_normed.png',
#    'units_strings.svg',
#    'errorbar_limits.pdf',
#    'mixed_collection.svg',
#    'hist_stacked_stepfilled.svg',
#    'polar_wrap_360.png',
#    'axhspan_epoch.pdf',
#    'markevery.png',
#    'formatter_ticker_004.png',
#    'polar_axes.png',
#    'axhspan_epoch.png',
#    'polar_rmin.svg',
#    'log_scales.svg',
#    'specgram_noise_linear.png',
#    'contour_colorbar.png',
#    'formatter_ticker_005.svg',
#    'errorbar_limits.svg',
#    'markevery_polar.svg',
#    'markevery_log_scales.pdf',
#    'markevery_linear_scales.pdf',
#    'polar_rmin.pdf',
#    'boxplot_no_inverted_whisker.png',
#    'psd_freqs.png',
#    'hist_stacked_stepfilled_alpha.pdf',
#    'formatter_ticker_005.png',
#    'transparent_markers.svg',
#    'bxp_withmean_line.png',
#    'test_alpha.svg',
#    'contour_hatching.png',
#    'violinplot_vert_showextrema.png',
#    'offset_points.svg',
#    'formatter_ticker_005.pdf',
#    'boxplot_mod_artists_after_plotting.png',
#    'step_linestyle.pdf',
#    'hist_stacked_bar.svg',
#    'bxp_withnotch.png',
#    'hist_steplog.svg',
#    'specgram_magnitude_noise.png',
#    'markevery_line.svg',
#    'errorbar_zorder.svg',
#    'hexbin_log.png',
#    'vertex_markers.png',
#    'nonfinite_limits.png',
#    'specgram_freqs_linear.png',
#    'imshow_clip.png',
#    'polar_units_2.png',
#    'violinplot_vert_showmeans.png',
#    'contour_colorbar.pdf',
#    'marker_edges.svg',
#    'polar_theta_position.png',
#    'formatter_large_small.png',
#    'single_date.png',
#    'const_xy.png',
#    'twin_spines.png',
#    'formatter_ticker_002.svg',
#    'symlog.png',
#    'single_point.pdf',
#    'angle_spectrum_freqs.png',
#    'test_alpha.pdf',
#    'bxp_customwidths.png',
#    'transparent_markers.png',
#    'transparent_markers.pdf',
#    'eventplot.svg',
#    'specgram_magnitude_noise_linear.png',
#    'boxplot.png',
#    'markevery_log_scales.png',
#    'formatter_large_small.svg',
#    'violinplot_vert_baseline.png',
#    'markevery_line.png',
#    'phase_spectrum_freqs.png',
#    'markevery_line.pdf',
#    'polar_axes.pdf',
#    'imshow.png',
#    'stackplot_test_image.svg',
#    'arc_ellipse.png',
#    'polycollection_joinstyle.svg',
#    'polar_units.png',
#    'polar_wrap_360.svg',
#    'twin_axis_locaters_formatters.svg',
#    'hist_step.png',
#    'markevery_linear_scales.svg',
#    'fill_units.png',
#    'marker_edges.png',
#    'canonical.png',
#    'boxplot_autorange_whiskers.png',
#    'pcolormesh.svg',
#    'magnitude_spectrum_noise_linear.png',
#    'specgram_magnitude_freqs_linear.png',
#    'nonfinite_limits.svg',
#    'hist_stacked.png',
#    'hist2d_transpose.png',
#    'bxp_custompatchartist.png',
#    'const_xy.svg',
#    'specgram_freqs.png',
#    'symlog.svg',
#    'contour_colorbar.svg',
#    'hist_step_horiz.png',
#    'hist_stacked_normed.svg',
#    'phase_spectrum_noise.png',
#    'pie_ccw_true.png',
#    'markevery.svg',
#    'hist_offset.svg',
#    'eventplot.pdf',
#    'bxp_horizontal.png',
#    'specgram_phase_freqs.png',
#    'hist_stacked_step.svg',
#    'contour_hatching.pdf',
#    'stackplot_test_image.pdf',
#    'formatter_ticker_003.pdf',
#    'hist_steplog.pdf',
#    'violinplot_vert_custompoints_200.png',
#    'axvspan_epoch.svg',
#    'polar_rlabel_position.svg',
#    'log_scales.pdf',
#    'mollweide_grid.pdf',
#    'formatter_ticker_003.png',
#    'polar_units.pdf',
#    'errorbar_zorder.png',
#    'violinplot_horiz_baseline.png',
#    'polar_coords.svg',
#    'errorbar_zorder.pdf',
#    'markevery_linear_scales_zoomed.pdf',
#    'autoscale_tiny_range.pdf',
#    'boxplot_sym.png',
#    'hist_stacked_step.pdf',
#    'polar_axes.svg',
#    'bxp_patchartist.png',
#    'units_strings.pdf',
#    'violinplot_horiz_showall.png',
#    'pie_linewidth_0.png',
#    'bxp_nocaps.png',
#    'polar_wrap_180.svg',
#    'errorbar_mixed.png',
#    'step_linestyle.svg',
#    'mollweide_grid.png',
#    'bxp_scalarwidth.png',
#    'violinplot_horiz_showextrema.png',
#    'errorbar_mixed.svg',
#    'boxplot_sym2.png',
#    'stackplot_test_baseline.png',
#    'offset_points.pdf',
#    'bxp_baseline.png',
#    'mollweide_grid.svg',
#    'errorbar_basic.pdf',
#    'hist_log.pdf',
#    'violinplot_vert_showall.png',
#    'violinplot_vert_showmedians.png',
#    'marker_edges.pdf',
#    'polycollection_joinstyle.pdf',
#    'violinplot_horiz_showmedians.png',
#    'hist_log.svg',
#    'hist_stacked_step.png',
#    'nonfinite_limits.pdf',
#    'polar_coords.png',
#    'specgram_angle_freqs.png',
#    'errorbar_basic.png',
#    'autoscale_tiny_range.svg',
#    'single_date.svg',
#    'boxplot_with_CIarray.png',
#    'formatter_ticker_004.pdf',
#    'pcolor_datetime_axis.png',
#    'single_point.svg']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_tightlayout',
#   [],
#   ['tight_layout6.svg',
#    'tight_layout3.png',
#    'tight_layout6.pdf',
#    'tight_layout4.png',
#    'tight_layout3.pdf',
#    'tight_layout1.pdf',
#    'tight_layout6.png',
#    'tight_layout8.svg',
#    'tight_layout5.png',
#    'tight_layout8.pdf',
#    'tight_layout1.png',
#    'tight_layout4.svg',
#    'tight_layout7.pdf',
#    'tight_layout2.svg',
#    'tight_layout8.png',
#    'tight_layout2.png',
#    'tight_layout5.svg',
#    'tight_layout5.pdf',
#    'tight_layout4.pdf',
#    'tight_layout1.svg',
#    'tight_layout2.pdf',
#    'tight_layout7.png',
#    'tight_layout7.svg',
#    'tight_layout3.svg']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_collections',
#   [],
#   ['EventCollection_plot__set_linelength.svg',
#    'EventCollection_plot__set_linewidth.pdf',
#    'EventCollection_plot__set_color.png',
#    'EventCollection_plot__default.svg',
#    'EventCollection_plot__set_orientation.pdf',
#    'EventCollection_plot__set_positions.pdf',
#    'EventCollection_plot__set_lineoffset.svg',
#    'EventCollection_plot__set_positions.svg',
#    'EventCollection_plot__add_positions.png',
#    'EventCollection_plot__extend_positions.pdf',
#    'regularpolycollection_rotate.png',
#    'EventCollection_plot__append_positions.svg',
#    'EventCollection_plot__set_linewidth.png',
#    'EventCollection_plot__switch_orientation__2x.png',
#    'EventCollection_plot__set_orientation.svg',
#    'EventCollection_plot__set_linestyle.png',
#    'EventCollection_plot__set_orientation.png',
#    'EventCollection_plot__switch_orientation.svg',
#    'EventCollection_plot__set_linelength.png',
#    'EventCollection_plot__append_positions.pdf',
#    'EventCollection_plot__extend_positions.png',
#    'EventCollection_plot__set_color.pdf',
#    'EventCollection_plot__default.png',
#    'polycollection_close.png',
#    'EventCollection_plot__switch_orientation.pdf',
#    'EventCollection_plot__add_positions.svg',
#    'EventCollection_plot__switch_orientation.png',
#    'EventCollection_plot__set_lineoffset.pdf',
#    'EventCollection_plot__add_positions.pdf',
#    'EventCollection_plot__set_linestyle.svg',
#    'EventCollection_plot__set_linelength.pdf',
#    'EventCollection_plot__set_lineoffset.png',
#    'EventCollection_plot__switch_orientation__2x.svg',
#    'regularpolycollection_scale.png',
#    'EventCollection_plot__append_positions.png',
#    'EllipseCollection_test_image.png',
#    'EventCollection_plot__extend_positions.svg',
#    'EventCollection_plot__set_linestyle.pdf',
#    'EventCollection_plot__set_linewidth.svg',
#    'EventCollection_plot__switch_orientation__2x.pdf',
#    'EventCollection_plot__set_positions.png',
#    'EventCollection_plot__set_color.svg',
#    'EventCollection_plot__default.pdf']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_mathtext',
#   [],
#   ['mathfont_stixsans_07.png',
#    'mathtext_stix_39.pdf',
#    'mathtext_stix_28.pdf',
#    'mathtext_stixsans_67.pdf',
#    'mathtext_stix_33.png',
#    'mathtext_cm_12.pdf',
#    'mathfont_stix_42.png',
#    'mathtext_stix_26.png',
#    'mathtext_cm_21.pdf',
#    'mathtext_stix_34.png',
#    'mathtext_stixsans_34.svg',
#    'mathtext_cm_37.svg',
#    'mathtext_stix_07.pdf',
#    'mathtext_stixsans_22.svg',
#    'mathfont_stix_31.png',
#    'mathtext_cm_16.svg',
#    'mathfont_stix_09.png',
#    'mathtext_stixsans_18.pdf',
#    'mathfont_stix_39.png',
#    'mathtext_stixsans_05.pdf',
#    'mathtext_stix_55.svg',
#    'mathtext_stixsans_55.png',
#    'mathtext_stix_52.svg',
#    'mathtext_stix_18.png',
#    'mathtext_stixsans_38.png',
#    'mathtext_cm_11.pdf',
#    'mathfont_cm_05.png',
#    'mathtext_cm_05.png',
#    'mathfont_stix_46.png',
#    'mathfont_stixsans_13.png',
#    'mathfont_stix_19.png',
#    'mathtext_stixsans_51.pdf',
#    'mathtext_stix_14.png',
#    'mathtext_stix_34.svg',
#    'mathtext_stix_48.pdf',
#    'mathtext_stixsans_36.svg',
#    'mathtext_cm_36.pdf',
#    'mathtext_cm_19.svg',
#    'mathtext_stixsans_61.svg',
#    'mathtext_stix_06.png',
#    'mathtext_stixsans_04.svg',
#    'mathtext_stix_38.pdf',
#    'mathtext_cm_08.svg',
#    'mathfont_stixsans_33.png',
#    'mathtext_stixsans_09.png',
#    'mathtext_cm_20.svg',
#    'mathfont_cm_30.png',
#    'mathfont_stixsans_55.png',
#    'mathfont_stix_02.png',
#    'mathfont_stix_53.png',
#    'mathtext_cm_18.svg',
#    'mathtext_stixsans_28.png',
#    'mathfont_stixsans_02.png',
#    'mathfont_stixsans_56.png',
#    'mathtext_stix_63.svg',
#    'mathtext_stixsans_54.svg',
#    'mathtext_cm_35.svg',
#    'mathtext_stixsans_60.png',
#    'mathtext_stixsans_21.png',
#    'mathtext_stixsans_21.svg',
#    'mathfont_cm_02.png',
#    'mathtext_cm_18.png',
#    'mathtext_stixsans_49.svg',
#    'mathtext_cm_10.svg',
#    'mathtext_cm_59.pdf',
#    'mathtext_stixsans_30.png',
#    'mathtext_stix_22.svg',
#    'mathtext_stix_02.svg',
#    'mathtext_stix_26.pdf',
#    'mathtext_cm_24.svg',
#    'mathtext_stixsans_50.png',
#    'mathtext_cm_14.png',
#    'mathfont_stix_45.png',
#    'mathtext_stix_35.svg',
#    'mathfont_cm_47.png',
#    'mathtext_stix_51.pdf',
#    'mathtext_cm_42.png',
#    'mathtext_stix_20.svg',
#    'mathtext_stix_66.pdf',
#    'mathtext_cm_27.svg',
#    'mathfont_stixsans_03.png',
#    'mathfont_stixsans_35.png',
#    'mathtext_cm_01.svg',
#    'mathfont_cm_01.png',
#    'mathfont_stix_18.png',
#    'mathfont_stix_48.png',
#    'mathtext_cm_46.pdf',
#    'mathtext_stixsans_59.svg',
#    'mathtext_cm_08.pdf',
#    'mathtext_stix_22.pdf',
#    'mathtext_stixsans_01.pdf',
#    'mathtext_stix_60.png',
#    'mathtext_stix_28.svg',
#    'mathtext_stix_41.pdf',
#    'mathfont_cm_57.png',
#    'mathfont_cm_12.png',
#    'mathtext_cm_03.pdf',
#    'mathtext_stixsans_44.pdf',
#    'mathtext_stixsans_42.png',
#    'mathtext_stix_06.pdf',
#    'mathfont_cm_33.png',
#    'mathtext_stixsans_52.png',
#    'mathtext_cm_60.png',
#    'mathtext_stixsans_63.svg',
#    'mathtext_cm_03.svg',
#    'mathfont_cm_36.png',
#    'mathtext_stixsans_59.png',
#    'mathtext_stix_25.svg',
#    'mathfont_stixsans_34.png',
#    'mathtext_cm_40.png',
#    'mathtext_cm_65.svg',
#    'mathtext_cm_57.svg',
#    'mathfont_cm_40.png',
#    'mathtext_stix_60.pdf',
#    'mathtext_cm_26.svg',
#    'mathfont_cm_56.png',
#    'mathtext_stixsans_46.pdf',
#    'mathtext_stix_66.svg',
#    'mathtext_cm_51.png',
#    'mathfont_stix_38.png',
#    'mathfont_cm_32.png',
#    'mathtext_stixsans_07.pdf',
#    'mathtext_cm_14.svg',
#    'mathtext_cm_25.pdf',
#    'mathtext_stixsans_16.svg',
#    'mathtext_stix_62.svg',
#    'mathtext_stix_23.pdf',
#    'mathfont_stix_34.png',
#    'mathtext_cm_34.png',
#    'mathtext_cm_31.pdf',
#    'mathtext_stix_09.svg',
#    'mathtext_cm_10.png',
#    'mathtext_cm_59.svg',
#    'mathtext_stixsans_35.pdf',
#    'mathfont_cm_26.png',
#    'mathfont_stixsans_27.png',
#    'mathtext_stixsans_11.pdf',
#    'mathtext_cm_45.png',
#    'mathtext_cm_35.png',
#    'mathtext_stixsans_30.svg',
#    'mathtext_cm_28.pdf',
#    'mathtext_cm_05.pdf',
#    'mathtext_stix_53.pdf',
#    'mathtext_stix_05.svg',
#    'mathtext_stixsans_52.pdf',
#    'mathtext_stix_19.png',
#    'mathtext_stixsans_09.svg',
#    'mathtext_cm_11.svg',
#    'mathtext_stixsans_26.png',
#    'mathtext_stix_54.png',
#    'mathfont_stix_10.png',
#    'mathtext_stix_13.png',
#    'mathtext_stixsans_49.png',
#    'mathtext_stix_19.pdf',
#    'mathtext_stixsans_45.pdf',
#    'mathfont_cm_10.png',
#    'mathtext_cm_00.svg',
#    'mathtext_cm_38.pdf',
#    'mathtext_cm_36.png',
#    'mathtext_stix_52.png',
#    'mathtext_stixsans_33.svg',
#    'mathtext_cm_44.png',
#    'mathtext_stixsans_46.png',
#    'mathtext_cm_03.png',
#    'mathfont_stix_57.png',
#    'mathfont_stixsans_31.png',
#    'mathtext_stixsans_38.svg',
#    'mathtext_stixsans_19.pdf',
#    'mathtext_stix_15.pdf',
#    'mathtext_stixsans_11.svg',
#    'mathtext_stixsans_67.svg',
#    'mathtext_stix_55.pdf',
#    'mathfont_stixsans_15.png',
#    'mathtext_stixsans_46.svg',
#    'mathtext_stix_17.svg',
#    'mathtext_stixsans_10.png',
#    'mathtext_cm_41.svg',
#    'mathtext_stixsans_04.png',
#    'mathtext_stixsans_60.svg',
#    'mathfont_cm_53.png',
#    'mathtext_stixsans_07.png',
#    'mathfont_stix_59.png',
#    'mathfont_stix_44.png',
#    'mathtext_stix_14.svg',
#    'mathtext_stix_64.png',
#    'mathtext_stixsans_30.pdf',
#    'mathtext_stixsans_27.pdf',
#    'mathtext_stixsans_28.svg',
#    'mathtext_cm_55.svg',
#    'mathtext_cm_62.png',
#    'mathtext_cm_25.svg',
#    'mathtext_stixsans_55.svg',
#    'mathfont_stixsans_40.png',
#    'mathfont_stixsans_19.png',
#    'mathfont_cm_23.png',
#    'mathtext_stixsans_19.png',
#    'mathtext_cm_00.png',
#    'mathtext_stixsans_43.png',
#    'mathfont_stix_27.png',
#    'mathfont_cm_38.png',
#    'mathtext_cm_02.png',
#    'mathtext_stix_43.pdf',
#    'mathtext_cm_53.svg',
#    'mathtext_stixsans_26.pdf',
#    'mathtext_stixsans_43.svg',
#    'mathtext_cm_66.png',
#    'mathfont_cm_15.png',
#    'mathtext_cm_02.svg',
#    'mathfont_cm_09.png',
#    'mathtext_cm_66.pdf',
#    'mathtext_stix_29.pdf',
#    'mathfont_stixsans_39.png',
#    'mathfont_stix_40.png',
#    'mathfont_cm_20.png',
#    'mathtext_stix_37.pdf',
#    'mathtext_stixsans_15.png',
#    'mathtext_stixsans_34.png',
#    'mathtext_stix_12.pdf',
#    'mathtext_cm_04.png',
#    'mathtext_stix_27.svg',
#    'mathtext_stix_04.png',
#    'mathtext_stixsans_25.svg',
#    'mathtext_stix_36.svg',
#    'mathtext_cm_35.pdf',
#    'mathfont_cm_25.png',
#    'mathtext_cm_19.pdf',
#    'mathfont_stix_55.png',
#    'mathfont_stixsans_49.png',
#    'mathtext_stixsans_00.png',
#    'mathtext_stix_61.pdf',
#    'mathtext_stix_47.png',
#    'mathtext_cm_20.png',
#    'mathfont_stixsans_14.png',
#    'mathtext_stixsans_66.svg',
#    'mathtext_cm_19.png',
#    'mathtext_stixsans_44.png',
#    'mathtext_cm_30.svg',
#    'mathtext_stix_31.pdf',
#    'mathtext_stixsans_03.png',
#    'mathtext_stixsans_12.pdf',
#    'mathtext_stix_08.svg',
#    'mathtext_cm_66.svg',
#    'mathtext_stixsans_26.svg',
#    'mathtext_stixsans_62.pdf',
#    'mathtext_cm_27.pdf',
#    'mathtext_stix_16.png',
#    'mathtext_cm_43.pdf',
#    'mathtext_stix_67.pdf',
#    'mathfont_stixsans_20.png',
#    'mathtext_stix_32.svg',
#    'mathtext_stix_67.png',
#    'mathtext_stixsans_57.svg',
#    'mathtext_cm_44.pdf',
#    'mathtext_stixsans_08.png',
#    'mathfont_cm_18.png',
#    'mathfont_stixsans_41.png',
#    'mathfont_stix_26.png',
#    'mathfont_stix_11.png',
#    'mathtext_cm_09.svg',
#    'mathtext_cm_51.svg',
#    'mathtext_cm_54.pdf',
#    'mathfont_stixsans_24.png',
#    'mathtext_stix_01.pdf',
#    'mathtext_stix_50.svg',
#    'mathtext_stix_64.pdf',
#    'mathfont_cm_58.png',
#    'mathtext_stixsans_24.pdf',
#    'mathfont_stix_52.png',
#    'mathtext_stix_02.pdf',
#    'mathtext_stixsans_64.png',
#    'mathtext_stix_51.svg',
#    'mathtext_stixsans_64.svg',
#    'mathfont_stix_51.png',
#    'mathfont_cm_00.png',
#    'mathfont_stixsans_58.png',
#    'mathtext_stixsans_13.png',
#    'mathtext_stixsans_08.svg',
#    'mathtext_stixsans_13.svg',
#    'mathfont_stix_41.png',
#    'mathtext_cm_62.svg',
#    'mathtext_cm_30.pdf',
#    'mathtext_stixsans_06.pdf',
#    'mathtext_stixsans_45.svg',
#    'mathfont_stix_50.png',
#    'mathtext_cm_11.png',
#    'mathfont_stixsans_37.png',
#    'mathtext_stix_67.svg',
#    'mathfont_cm_27.png',
#    'mathfont_stix_37.png',
#    'mathtext_stixsans_14.png',
#    'mathtext_stixsans_35.svg',
#    'mathtext_stixsans_16.png',
#    'mathtext_stix_11.svg',
#    'mathtext_stix_27.png',
#    'mathtext_cm_13.png',
#    'mathtext_cm_29.png',
#    'mathtext_stixsans_57.png',
#    'mathtext_cm_53.pdf',
#    'mathtext_stixsans_17.svg',
#    'mathtext_cm_07.svg',
#    'mathfont_stix_12.png',
#    'mathtext_cm_56.svg',
#    'mathfont_stixsans_42.png',
#    'mathfont_cm_08.png',
#    'mathtext_cm_54.svg',
#    'mathtext_stix_03.svg',
#    'mathfont_stixsans_47.png',
#    'mathtext_stixsans_53.png',
#    'mathtext_cm_50.pdf',
#    'mathtext_stixsans_39.svg',
#    'mathfont_stixsans_06.png',
#    'mathtext_stix_47.pdf',
#    'mathtext_stixsans_18.png',
#    'mathtext_stix_52.pdf',
#    'mathtext_cm_47.pdf',
#    'mathtext_cm_01.png',
#    'mathtext_stix_46.png',
#    'mathtext_cm_56.pdf',
#    'mathtext_stix_00.svg',
#    'mathtext_stixsans_58.pdf',
#    'mathfont_cm_37.png',
#    'mathtext_stix_48.svg',
#    'mathfont_stixsans_18.png',
#    'mathtext_cm_61.svg',
#    'mathtext_cm_64.pdf',
#    'mathtext_stix_41.svg',
#    'mathtext_stix_37.svg',
#    'mathtext_stix_39.png',
#    'mathfont_stix_49.png',
#    'mathtext_cm_36.svg',
#    'mathfont_cm_07.png',
#    'mathfont_stix_01.png',
#    'mathtext_stix_16.pdf',
#    'mathfont_stixsans_36.png',
#    'mathtext_cm_48.pdf',
#    'mathtext_stixsans_49.pdf',
#    'mathtext_stixsans_25.png',
#    'mathtext_stixsans_62.png',
#    'mathtext_stix_46.pdf',
#    'mathtext_stixsans_50.pdf',
#    'mathtext_cm_60.pdf',
#    'mathtext_cm_07.pdf',
#    'mathtext_stix_15.png',
#    'mathtext_stix_24.pdf',
#    'mathfont_stix_25.png',
#    'mathfont_stixsans_17.png',
#    'mathfont_stix_54.png',
#    'mathtext_cm_33.pdf',
#    'mathtext_stix_42.png',
#    'mathtext_stix_58.png',
#    'mathtext_stix_16.svg',
#    'mathtext_cm_65.png',
#    'mathtext_stix_33.pdf',
#    'mathtext_stix_45.pdf',
#    'mathtext_stix_54.svg',
#    'mathtext_cm_20.pdf',
#    'mathtext_stix_53.svg',
#    'mathtext_cm_15.pdf',
#    'mathfont_cm_46.png',
#    'mathtext_cm_42.svg',
#    'mathtext_stixsans_25.pdf',
#    'mathfont_cm_22.png',
#    'mathtext_stixsans_12.png',
#    'mathtext_cm_04.pdf',
#    'mathfont_stixsans_23.png',
#    'mathtext_cm_31.png',
#    'mathfont_cm_24.png',
#    'mathtext_cm_00.pdf',
#    'mathfont_stixsans_29.png',
#    'mathtext_cm_59.png',
#    'mathtext_cm_24.pdf',
#    'mathtext_cm_12.svg',
#    'mathtext_stix_42.pdf',
#    'mathtext_cm_60.svg',
#    'mathtext_cm_18.pdf',
#    'mathtext_stixsans_10.pdf',
#    'mathfont_stixsans_51.png',
#    'mathtext_cm_39.png',
#    'mathtext_cm_43.png',
#    'mathtext_stix_10.pdf',
#    'mathtext_stix_04.pdf',
#    'mathtext_cm_13.svg',
#    'mathfont_stixsans_10.png',
#    'mathtext_stixsans_47.svg',
#    'mathtext_cm_48.png',
#    'mathtext_stix_43.png',
#    'mathfont_cm_44.png',
#    'mathtext_stixsans_06.svg',
#    'mathtext_cm_06.pdf',
#    'mathtext_stix_12.svg',
#    'mathtext_cm_26.png',
#    'mathfont_cm_19.png',
#    'mathfont_cm_52.png',
#    'mathtext_stix_19.svg',
#    'mathtext_cm_51.pdf',
#    'mathtext_cm_28.svg',
#    'mathtext_stix_01.svg',
#    'mathtext_cm_55.pdf',
#    'mathtext_stixsans_43.pdf',
#    'mathtext_cm_38.png',
#    'mathtext_stixsans_23.png',
#    'mathtext_cm_29.svg',
#    'mathtext_stix_40.svg',
#    'mathtext_cm_48.svg',
#    'mathtext_stix_36.png',
#    'mathtext_cm_23.png',
#    'mathfont_cm_42.png',
#    'mathtext_stix_20.pdf',
#    'mathtext_stixsans_54.pdf',
#    'mathtext_stixsans_10.svg',
#    'mathtext_cm_61.pdf',
#    'mathfont_cm_49.png',
#    'mathtext_cm_61.png',
#    'mathtext_cm_07.png',
#    'mathtext_stix_22.png',
#    'mathtext_stixsans_17.png',
#    'mathtext_stixsans_62.svg',
#    'mathtext_stixsans_51.svg',
#    'mathtext_stixsans_17.pdf',
#    'mathtext_stixsans_31.pdf',
#    'mathtext_cm_08.png',
#    'mathtext_cm_58.svg',
#    'mathtext_cm_09.png',
#    'mathtext_stix_35.png',
#    'mathtext_stixsans_19.svg',
#    'mathtext_stix_42.svg',
#    'mathfont_stix_32.png',
#    'mathtext_stix_34.pdf',
#    'mathtext_stixsans_12.svg',
#    'mathtext_cm_52.png',
#    'mathtext_stixsans_24.png',
#    'mathtext_stix_21.pdf',
#    'mathfont_stix_05.png',
#    'mathtext_stix_14.pdf',
#    'mathtext_stix_62.pdf',
#    'mathtext_stix_06.svg',
#    'mathtext_stix_24.svg',
#    'mathtext_stixsans_02.pdf',
#    'mathtext_stix_64.svg',
#    'mathtext_stixsans_20.svg',
#    'mathtext_cm_29.pdf',
#    'mathfont_stix_21.png',
#    'mathfont_stixsans_52.png',
#    'mathtext_stixsans_33.pdf',
#    'mathtext_stix_40.pdf',
#    'mathtext_stixsans_42.pdf',
#    'mathtext_cm_21.svg',
#    'mathtext_stixsans_05.png',
#    'mathfont_stixsans_26.png',
#    'mathtext_cm_01.pdf',
#    'mathtext_stix_17.png',
#    'mathtext_stix_35.pdf',
#    'mathfont_stixsans_50.png',
#    'mathtext_stix_03.pdf',
#    'mathfont_stixsans_54.png',
#    'mathtext_stix_18.svg',
#    'mathtext_stixsans_41.png',
#    'mathtext_cm_41.pdf',
#    'mathtext_stix_65.png',
#    'mathtext_stix_20.png',
#    'mathtext_cm_49.svg',
#    'mathtext_cm_58.pdf',
#    'mathtext_stix_33.svg',
#    'mathtext_stix_48.png',
#    'mathfont_stix_07.png',
#    'mathtext_stix_44.png',
#    'mathtext_stixsans_08.pdf',
#    'mathtext_cm_23.svg',
#    'mathfont_cm_45.png',
#    'mathtext_stixsans_63.png',
#    'mathtext_stix_27.pdf',
#    'mathtext_stix_01.png',
#    'mathtext_stixsans_22.pdf',
#    'mathtext_cm_56.png',
#    'mathtext_stix_11.png',
#    'mathtext_cm_06.svg',
#    'mathtext_cm_14.pdf',
#    'mathtext_stixsans_27.svg',
#    'mathfont_stix_15.png',
#    'mathtext_stixsans_34.pdf',
#    'mathtext_stixsans_13.pdf',
#    'mathtext_stixsans_50.svg',
#    'mathtext_stixsans_31.svg',
#    'mathfont_stixsans_11.png',
#    'mathtext_stix_10.png',
#    'mathtext_cm_43.svg',
#    'mathtext_stix_29.png',
#    'mathtext_stixsans_39.png',
#    'mathtext_stix_04.svg',
#    'mathtext_stixsans_66.png',
#    'mathfont_stix_20.png',
#    'mathfont_cm_35.png',
#    'mathfont_cm_11.png',
#    'mathfont_stixsans_09.png',
#    'mathtext_stixsans_35.png',
#    'mathtext_cm_63.png',
#    'mathfont_cm_55.png',
#    'mathtext_stixsans_22.png',
#    'mathtext_cm_63.svg',
#    'mathfont_stix_08.png',
#    'mathtext_cm_45.svg',
#    'mathtext_stixsans_28.pdf',
#    'mathfont_cm_06.png',
#    'mathtext_stixsans_39.pdf',
#    'mathtext_stix_23.png',
#    'mathfont_stixsans_08.png',
#    'mathtext_stixsans_11.png',
#    'mathtext_stixsans_61.pdf',
#    'mathtext_cm_40.pdf',
#    'mathtext_stix_25.pdf',
#    'mathtext_stix_40.png',
#    'mathfont_stixsans_48.png',
#    'mathfont_stix_16.png',
#    'mathtext_stix_00.png',
#    'mathfont_stixsans_38.png',
#    'mathfont_cm_13.png',
#    'mathfont_cm_29.png',
#    'mathtext_stix_60.svg',
#    'mathtext_stix_41.png',
#    'mathtext_stixsans_65.svg',
#    'mathtext_stix_09.pdf',
#    'mathtext_stix_37.png',
#    'mathtext_stixsans_64.pdf',
#    'mathtext_cm_12.png',
#    'mathtext_cm_15.svg',
#    'mathtext_stix_11.pdf',
#    'mathtext_stixsans_02.svg',
#    'mathfont_stix_33.png',
#    'mathtext_cm_32.pdf',
#    'mathtext_cm_34.svg',
#    'mathtext_stixsans_01.png',
#    'mathfont_stix_29.png',
#    'mathfont_stix_30.png',
#    'mathtext_stix_66.png',
#    'mathtext_cm_24.png',
#    'mathfont_stixsans_12.png',
#    'mathtext_cm_52.pdf',
#    'mathfont_stix_43.png',
#    'mathtext_stix_61.png',
#    'mathtext_stix_30.png',
#    'mathtext_stix_12.png',
#    'mathfont_stixsans_21.png',
#    'mathtext_stixsans_40.svg',
#    'mathtext_cm_57.png',
#    'mathfont_stixsans_28.png',
#    'mathtext_cm_65.pdf',
#    'mathfont_cm_34.png',
#    'mathtext_stixsans_05.svg',
#    'mathtext_stixsans_00.svg',
#    'mathtext_cm_47.svg',
#    'mathtext_stixsans_65.pdf',
#    'mathtext_cm_22.pdf',
#    'mathtext_stixsans_02.png',
#    'mathtext_stixsans_01.svg',
#    'mathtext_cm_42.pdf',
#    'mathtext_stix_61.svg',
#    'mathtext_cm_22.svg',
#    'mathfont_stixsans_53.png',
#    'mathfont_cm_21.png',
#    'mathtext_stix_54.pdf',
#    'mathfont_stix_24.png',
#    'mathtext_stixsans_00.pdf',
#    'mathtext_stix_15.svg',
#    'mathtext_stixsans_61.png',
#    'mathtext_stix_63.pdf',
#    'mathtext_stix_53.png',
#    'mathtext_stixsans_32.svg',
#    'mathtext_stixsans_14.pdf',
#    'mathtext_stixsans_33.png',
#    'mathtext_cm_52.svg',
#    'mathtext_cm_23.pdf',
#    'mathtext_stixsans_45.png',
#    'mathtext_stix_59.png',
#    'mathfont_cm_16.png',
#    'mathtext_cm_58.png',
#    'mathtext_stix_59.svg',
#    'mathtext_stixsans_48.pdf',
#    'mathtext_cm_64.svg',
#    'mathfont_stixsans_45.png',
#    'mathtext_stix_45.png',
#    'mathfont_cm_17.png',
#    'mathtext_stixsans_23.pdf',
#    'mathtext_stix_50.pdf',
#    'mathfont_stixsans_22.png',
#    'mathtext_stixsans_52.svg',
#    'mathtext_stix_31.png',
#    'mathfont_cm_39.png',
#    'mathfont_cm_54.png',
#    'mathtext_cm_34.pdf',
#    'mathtext_stix_65.svg',
#    'mathfont_cm_50.png',
#    'mathtext_cm_41.png',
#    'mathtext_stix_05.pdf',
#    'mathtext_stixsans_41.pdf',
#    'mathtext_stixsans_37.pdf',
#    'mathtext_stixsans_47.png',
#    'mathtext_stix_55.png',
#    'mathfont_stixsans_59.png',
#    'mathtext_stixsans_07.svg',
#    'mathtext_stix_46.svg',
#    'mathtext_cm_21.png',
#    'mathtext_stixsans_37.png',
#    'mathtext_stix_44.svg',
#    'mathtext_stix_03.png',
#    'mathtext_stix_29.svg',
#    'mathtext_cm_44.svg',
#    'mathtext_cm_10.pdf',
#    'mathfont_cm_31.png',
#    'mathtext_cm_09.pdf',
#    'mathtext_stix_23.svg',
#    'mathtext_cm_13.pdf',
#    'mathfont_cm_43.png',
#    'mathtext_cm_37.pdf',
#    'mathtext_stixsans_48.svg',
#    'mathtext_cm_02.pdf',
#    'mathtext_stix_39.svg',
#    'mathtext_stix_45.svg',
#    'mathtext_cm_46.svg',
#    'mathtext_cm_31.svg',
#    'mathfont_stix_28.png',
#    'mathtext_stixsans_40.png',
#    'mathtext_stixsans_56.pdf',
#    'mathtext_cm_50.svg',
#    'mathfont_stix_06.png',
#    'mathtext_cm_26.pdf',
#    'mathtext_cm_28.png',
#    'mathtext_stixsans_18.svg',
#    'mathfont_cm_14.png',
#    'mathtext_stixsans_56.svg',
#    'mathtext_stix_00.pdf',
#    'mathfont_cm_28.png',
#    'mathtext_stix_26.svg',
#    'mathtext_stix_57.pdf',
#    'mathtext_stix_49.pdf',
#    'mathtext_stixsans_53.svg',
#    'mathtext_cm_54.png',
#    'mathtext_cm_16.pdf',
#    'mathtext_stixsans_59.pdf',
#    'mathtext_stixsans_41.svg',
#    'mathfont_stixsans_57.png',
#    'mathtext_stixsans_15.svg',
#    'mathtext_cm_16.png',
#    'mathfont_stixsans_43.png',
#    'mathtext_stix_51.png',
#    'mathtext_stixsans_14.svg',
#    'mathtext_stix_49.png',
#    'mathtext_cm_38.svg',
#    'mathtext_stixsans_20.pdf',
#    'mathtext_stixsans_44.svg',
#    'mathfont_cm_48.png',
#    'mathtext_cm_22.png',
#    'mathfont_stixsans_32.png',
#    'mathtext_cm_53.png',
#    'mathtext_stix_13.pdf',
#    'mathtext_stixsans_09.pdf',
#    'mathfont_stix_00.png',
#    'mathtext_cm_27.png',
#    'mathtext_stix_57.png',
#    'mathtext_stix_62.png',
#    'mathtext_stix_10.svg',
#    'mathtext_stixsans_37.svg',
#    'mathfont_stix_22.png',
#    'mathtext_stixsans_36.pdf',
#    'mathtext_stix_56.svg',
#    'mathtext_cm_45.pdf',
#    'mathtext_stix_58.svg',
#    'mathtext_stixsans_29.pdf',
#    'mathfont_stixsans_44.png',
#    'mathfont_cm_41.png',
#    'mathtext_cm_30.png',
#    'mathtext_stix_32.png',
#    'mathtext_stixsans_54.png',
#    'mathtext_stixsans_32.pdf',
#    'mathtext_stix_13.svg',
#    'mathfont_stix_04.png',
#    'mathtext_stixsans_53.pdf',
#    'mathtext_stix_31.svg',
#    'mathtext_stix_32.pdf',
#    'mathtext_stixsans_21.pdf',
#    'mathtext_stix_50.png',
#    'mathtext_stix_08.pdf',
#    'mathfont_cm_51.png',
#    'mathtext_stixsans_15.pdf',
#    'mathtext_stix_21.svg',
#    'mathtext_stix_21.png',
#    'mathtext_stixsans_31.png',
#    'mathtext_cm_49.png',
#    'mathtext_stixsans_03.pdf',
#    'mathtext_stix_44.pdf',
#    'mathtext_cm_55.png',
#    'mathtext_cm_67.png',
#    'mathtext_cm_46.png',
#    'mathtext_stix_43.svg',
#    'mathfont_cm_03.png',
#    'mathtext_cm_25.png',
#    'mathtext_stix_08.png',
#    'mathtext_stix_07.png',
#    'mathtext_stix_49.svg',
#    'mathtext_cm_49.pdf',
#    'mathtext_stixsans_66.pdf',
#    'mathtext_stixsans_27.png',
#    'mathtext_stixsans_56.png',
#    'mathtext_cm_05.svg',
#    'mathtext_stix_58.pdf',
#    'mathtext_cm_39.svg',
#    'mathtext_stix_17.pdf',
#    'mathfont_stix_14.png',
#    'mathtext_cm_17.png',
#    'mathfont_stixsans_04.png',
#    'mathtext_stixsans_57.pdf',
#    'mathtext_stix_02.png',
#    'mathfont_stix_13.png',
#    'mathtext_cm_33.svg',
#    'mathfont_stixsans_30.png',
#    'mathtext_stixsans_38.pdf',
#    'mathfont_stix_03.png',
#    'mathtext_cm_57.pdf',
#    'mathtext_stixsans_36.png',
#    'mathfont_stix_47.png',
#    'mathtext_stix_38.svg',
#    'mathtext_stixsans_06.png',
#    'mathtext_stixsans_03.svg',
#    'mathtext_stixsans_29.png',
#    'mathtext_stixsans_67.png',
#    'mathtext_stixsans_20.png',
#    'mathtext_cm_32.svg',
#    'mathtext_cm_67.pdf',
#    'mathfont_stixsans_46.png',
#    'mathtext_stixsans_04.pdf',
#    'mathtext_cm_33.png',
#    'mathtext_cm_63.pdf',
#    'mathtext_stixsans_60.pdf',
#    'mathtext_stix_47.svg',
#    'mathtext_stix_36.pdf',
#    'mathfont_stixsans_25.png',
#    'mathtext_cm_47.png',
#    'mathtext_stixsans_42.svg',
#    'mathtext_stixsans_29.svg',
#    'mathfont_stixsans_05.png',
#    'mathfont_stix_35.png',
#    'mathtext_stixsans_24.svg',
#    'mathtext_cm_67.svg',
#    'mathfont_stix_17.png',
#    'mathfont_stix_56.png',
#    'mathtext_cm_15.png',
#    'mathtext_cm_32.png',
#    'mathtext_stixsans_65.png',
#    'mathtext_cm_37.png',
#    'mathtext_stix_56.png',
#    'mathtext_cm_06.png',
#    'mathtext_cm_39.pdf',
#    'mathtext_cm_50.png',
#    'mathfont_stixsans_01.png',
#    'mathtext_stix_28.png',
#    'mathfont_stix_58.png',
#    'mathtext_stix_56.pdf',
#    'mathtext_stix_07.svg',
#    'mathtext_stixsans_40.pdf',
#    'mathfont_stixsans_00.png',
#    'mathfont_cm_59.png',
#    'mathtext_stix_18.pdf',
#    'mathtext_cm_17.pdf',
#    'mathtext_stix_05.png',
#    'mathtext_stix_30.svg',
#    'mathfont_cm_04.png',
#    'mathtext_stixsans_58.svg',
#    'mathtext_stixsans_32.png',
#    'mathtext_stix_25.png',
#    'mathfont_stix_36.png',
#    'mathtext_stix_09.png',
#    'mathtext_stix_30.pdf',
#    'mathtext_cm_17.svg',
#    'mathtext_stix_57.svg',
#    'mathtext_stixsans_51.png',
#    'mathtext_stixsans_55.pdf',
#    'mathtext_stixsans_23.svg',
#    'mathtext_cm_62.pdf',
#    'mathtext_stixsans_48.png',
#    'mathtext_stix_63.png',
#    'mathfont_stix_23.png',
#    'mathtext_stixsans_47.pdf',
#    'mathtext_stix_24.png',
#    'mathtext_stix_65.pdf',
#    'mathtext_stixsans_16.pdf',
#    'mathtext_cm_64.png',
#    'mathtext_stixsans_63.pdf',
#    'mathtext_stix_59.pdf',
#    'mathtext_stix_38.png',
#    'mathtext_stixsans_58.png',
#    'mathtext_cm_40.svg',
#    'mathtext_cm_04.svg',
#    'mathfont_stixsans_16.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_image',
#   [],
#   ['no_interpolation_origin.pdf',
#    'image_composite_background.png',
#    'image_clip.png',
#    'image_interps.svg',
#    'imshow.pdf',
#    'bbox_image_inverted.png',
#    'image_interps.png',
#    'image_composite_alpha.pdf',
#    'no_interpolation_origin.svg',
#    'image_clip.pdf',
#    'imshow.svg',
#    'image_composite_background.pdf',
#    'image_cliprect.pdf',
#    'interp_nearest_vs_none.svg',
#    'image_interps.pdf',
#    'image_composite_alpha.png',
#    'no_interpolation_origin.png',
#    'rasterize_10dpi.svg',
#    'image_cliprect.png',
#    'figimage-0.png',
#    'imshow.png',
#    'bbox_image_inverted.pdf',
#    'image_cliprect.svg',
#    'image_shift.svg',
#    'uint16.tif',
#    'interp_nearest_vs_none.pdf',
#    'image_composite_background.svg',
#    'figimage-1.png',
#    'rasterize_10dpi.pdf',
#    'image_shift.pdf',
#    'image_clip.svg',
#    'image_composite_alpha.svg']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_contour',
#   [],
#   ['contour_manual_colors_and_levels.png',
#    'contour_manual_labels.svg',
#    'contour_manual_labels.png',
#    'contour_datetime_axis.png',
#    'contour_test_label_transforms.png',
#    'contour_manual_labels.pdf']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_artist',
#   [],
#   ['clip_path_clipping.svg',
#    'clip_path_clipping.pdf',
#    'clip_path_clipping.png']),
#  ('/tech/local/anaconda/1/lib/python2.7/site-packages/matplotlib/tests/baseline_images/test_bbox_tight',
#   [],
#   ['bbox_inches_tight.svg',
#    'bbox_inches_tight_raster.png',
#    'bbox_inches_tight_suptile_legend.svg',
#    'bbox_inches_tight_suptile_legend.pdf',
#    'bbox_inches_tight_clipping.pdf',
#    'bbox_inches_tight_raster.pdf',
#    'bbox_inches_tight_raster.svg',
#    'bbox_inches_tight.pdf',
#    'bbox_inches_tight.png',
#    'bbox_inches_tight_suptile_legend.png',
#    'bbox_inches_tight_clipping.png',
#    'bbox_inches_tight_clipping.svg'])]

# %%
[x for x in os.listdir(pk_path) if os.path.isdir(os.path.join(pk_path,x))]
# Out:
# ['delaunay',
#  'axes',
#  'mpl-data',
#  'style',
#  'sphinxext',
#  'tri',
#  'backends',
#  'compat',
#  'testing',
#  'projections',
#  'tests']

# %% [markdown]
# https://chrisyeh96.github.io/2017/08/08/definitive-guide-python-imports.html
#
# Remarque : importer un nom suppose une forme de résolution de ce nom. Python va chercher dans différents endroit séquentiellement et l'ordre dans lequel il y va peut avoir un impact (d'autant que certains de ces endroit dépendent que comment est exécuté la commande : dans un REPL, dans un script, etc.). L'article ci-dessus l'explique très bien.
#
# A lire : https://code.tutsplus.com/tutorials/what-are-python-namespaces-and-why-are-they-needed--cms-28598
#
# Remarque : pour lister l'ensemble des objets (classes, fonctions et objets instanciés liés à un nom) rendu disponibles par l'import d'un module/package : built-in function dir(). Attention : il faut que le module/package ait été importé.
#
# import some_module : a pour effet d'exécuter le script some_module.py et en particulier de peupler le namespace (à préciser) de tous les noms assignés à des objets par l'exécution du script.
# import some_package ou import some_package.subpackage : a pour effet d'éxécuter le __init__.py du package et de peupler le namespace de tous les noms assignés à des objets dans l'exécution de ce script. Attention, le script __init__.py peut tout à fait comporter des import statements, idem lors de l'import d'un module qui correspond en fait à l'exécution du script.
#
# * ```import my_package``` : seuls les objets instanciés à l'exécution de __init__.py sont disponibles. Invoquer un de ces objets X requiert la syntaxe ```my_package.X```. Si le fichier __init__.py est vide comme cela peut être fréquemment le cas, on a effectivement rien importé du tout.
# * ```import my_package.sub_pk``` : idem, seuls les objets instanciés par le __init__.py du sub-package (mais pas ceux du __init__.py de my_package - à confirmer -) sous la syntaxe ```my_package.sub_pk.X```.
# * ```import my_package.sub_pk.module``` : seuls les objets instanciés par l'exécution de module.py sont disponibles. On importe ici un module et non un package, les __init__.py ne sont pas exécutés (à confirmer). Cette écriture peut prêter à confusion, quand on écrit ```matplotlib.delaunay.interpolate```, on ne sait pas si ```interpolate``` est un module ou un package. La syntaxe pour appeler les objets de module reste la même : ```my_package.sub_pk.module.X```
#
# En revanche :
# * ```from my_package.sub_pk import module``` qui est équivalent à ```import my_package.sub_pk.module as module```permet d'alléger la syntaxe à ```module.X```
# * ```from my_package.sub_pk.module import some_class, some_func``` permet d'appeler les objets directement : ```x = Some_class()```, ```y = some_func(a, b)```
#
# On peut souvent préférer la première forme pour rendre explicite le fait que les objets utilisés sont ceux du module ```module```.
#
# Remarque : contrairement à ce qu'on pense ```import my_package``` n'induit pas l'import de l'ensemble des modules de my_package. Tout dépend de ce qu'on a écrit dans le  __init__.py. De même ```from my_package import *``` n'importe que ce qu'on a écrit dans __all__ ?
#
# Remarque : on peut passer à import un mélange de modules et de packages. La déclaration suivante est par exemple valide :
# ```import my_package as pck, my_package.subpck1, my_package.subpck2.module1 as mod1``` L'exécution de cette commande impliquera l'exécution des scripts __init__.py de my_package et de my_package.subpck1 ainsi que du script module1.py contenu dans le répertoire /my_package/subpck1.
#
# Remarque :
# help(module) marche (avec cette syntaxe si on a préalablement importé avec from pk.subpk import module. L'aide permet une visualisation de la structure du module.
# L'aide pour un objet particulier de module s'obtient alors avec help(module.my_obj)

# %%
import types
import os

pk_name = 'matplotlib'
pk_root_dir = os.path.dirname(plt.__file__)
pk_path = os.path.dirname(plt.__file__)

# def module_todict(module_names):
#     dc = {}
    
#     for name in module_names
#     dc.update({name:{}})
#     dc[name]['classes'] = [x for x in dir(name) if isinstance(getattr(x, name), types.ClassType)]
#     dc[name]['functions'] = [x for x in dir(name) if isinstance(getattr(x, name), types.FunctionType)]
#     dc[name]['data'] = [x for x in dir(name) if x not in dc[name]['classes']+dc[name]['functions']]
#     for a in dir(cm):
#     if isinstance(getattr(cm, a), types.FunctionType)


def pkdir_todict(paths):
    dc = {}
    
    if type(paths) is str: 
        paths = [paths]
        
    for pk_path in paths:
        subpk_items = [x for x in pk_path.split('/') if x not in pk_root_dir.split('/')[:-1]]
        dotted_pk_name = '.'.join(subpk_items)
        
        py_files = [x for x in os.listdir(pk_path) if x.endswith('.py')]
        is_submodule = ('__init__.py' in py_files)
        py_files.sort()
        
        if is_submodule:
            py_files.remove('__init__.py')
        
        if dotted_pk_name == pk_name:
            attr = 'pk'
        elif is_submodule:
            attr = 'subpk'
        else:
            continue
        
        key = pk_path.split('/')[-1]
        dc.update({key:{}})
        
        subdirs = [x for x in os.listdir(pk_path) if os.path.isdir(os.path.join(pk_path,x))]
        subdirs.sort()
        subdirs_paths = [os.path.join(pk_path,x) for x in subdirs]
        
        dc[key]['attr'] = attr
        dc[key]['name'] = dotted_pk_name
        dc[key]['modules_names'] = [x[:-3] for x in py_files]
        dc[key]['subpkgs_names'] = subdirs
        dc[key]['subpkgs'] = pkdir_todict(subdirs_paths)
        
    return dc

pk = pkdir_todict(os.path.dirname(plt.__file__))

# %%
pk
# Out:
# {'matplotlib': {'attr': 'pk',
#   'modules_names': ['_cm',
#    '_mathtext_data',
#    '_pylab_helpers',
#    'afm',
#    'animation',
#    'artist',
#    'axis',
#    'backend_bases',
#    'bezier',
#    'blocking_input',
#    'cbook',
#    'cm',
#    'collections',
#    'colorbar',
#    'colors',
#    'container',
#    'contour',
#    'dates',
#    'docstring',
#    'dviread',
#    'figure',
#    'finance',
#    'font_manager',
#    'fontconfig_pattern',
#    'gridspec',
#    'hatch',
#    'image',
#    'legend',
#    'legend_handler',
#    'lines',
#    'markers',
#    'mathtext',
#    'mlab',
#    'mpl',
#    'offsetbox',
#    'patches',
#    'path',
#    'patheffects',
#    'pylab',
#    'pyplot',
#    'quiver',
#    'rcsetup',
#    'sankey',
#    'scale',
#    'spines',
#    'stackplot',
#    'streamplot',
#    'table',
#    'texmanager',
#    'text',
#    'textpath',
#    'ticker',
#    'tight_bbox',
#    'tight_layout',
#    'transforms',
#    'type1font',
#    'units',
#    'widgets'],
#   'name': 'matplotlib',
#   'subpkgs': {'axes': {'attr': 'subpk',
#     'modules_names': ['_axes', '_base', '_subplots'],
#     'name': 'matplotlib.axes',
#     'subpkgs': {},
#     'subpkgs_names': []},
#    'backends': {'attr': 'subpk',
#     'modules_names': ['backend_agg',
#      'backend_cairo',
#      'backend_cocoaagg',
#      'backend_gdk',
#      'backend_gtk',
#      'backend_gtk3',
#      'backend_gtk3agg',
#      'backend_gtk3cairo',
#      'backend_gtkagg',
#      'backend_gtkcairo',
#      'backend_macosx',
#      'backend_mixed',
#      'backend_nbagg',
#      'backend_pdf',
#      'backend_pgf',
#      'backend_ps',
#      'backend_qt4',
#      'backend_qt4agg',
#      'backend_qt5',
#      'backend_qt5agg',
#      'backend_svg',
#      'backend_template',
#      'backend_tkagg',
#      'backend_webagg',
#      'backend_webagg_core',
#      'backend_wx',
#      'backend_wxagg',
#      'qt4_compat',
#      'qt_compat',
#      'tkagg',
#      'windowing'],
#     'name': 'matplotlib.backends',
#     'subpkgs': {'qt_editor': {'attr': 'subpk',
#       'modules_names': ['figureoptions', 'formlayout', 'formsubplottool'],
#       'name': 'matplotlib.backends.qt_editor',
#       'subpkgs': {},
#       'subpkgs_names': []}},
#     'subpkgs_names': ['Matplotlib.nib', 'qt_editor', 'web_backend']},
#    'compat': {'attr': 'subpk',
#     'modules_names': ['subprocess'],
#     'name': 'matplotlib.compat',
#     'subpkgs': {},
#     'subpkgs_names': []},
#    'delaunay': {'attr': 'subpk',
#     'modules_names': ['interpolate', 'testfuncs', 'triangulate'],
#     'name': 'matplotlib.delaunay',
#     'subpkgs': {},
#     'subpkgs_names': []},
#    'projections': {'attr': 'subpk',
#     'modules_names': ['geo', 'polar'],
#     'name': 'matplotlib.projections',
#     'subpkgs': {},
#     'subpkgs_names': []},
#    'sphinxext': {'attr': 'subpk',
#     'modules_names': ['ipython_console_highlighting',
#      'ipython_directive',
#      'mathmpl',
#      'only_directives',
#      'plot_directive'],
#     'name': 'matplotlib.sphinxext',
#     'subpkgs': {},
#     'subpkgs_names': []},
#    'style': {'attr': 'subpk',
#     'modules_names': ['core'],
#     'name': 'matplotlib.style',
#     'subpkgs': {},
#     'subpkgs_names': []},
#    'testing': {'attr': 'subpk',
#     'modules_names': ['compare', 'decorators', 'image_util', 'noseclasses'],
#     'name': 'matplotlib.testing',
#     'subpkgs': {'jpl_units': {'attr': 'subpk',
#       'modules_names': ['Duration',
#        'Epoch',
#        'EpochConverter',
#        'StrConverter',
#        'UnitDbl',
#        'UnitDblConverter',
#        'UnitDblFormatter'],
#       'name': 'matplotlib.testing.jpl_units',
#       'subpkgs': {},
#       'subpkgs_names': []}},
#     'subpkgs_names': ['jpl_units']},
#    'tests': {'attr': 'subpk',
#     'modules_names': ['test_agg',
#      'test_animation',
#      'test_arrow_patches',
#      'test_artist',
#      'test_axes',
#      'test_backend_bases',
#      'test_backend_pdf',
#      'test_backend_pgf',
#      'test_backend_ps',
#      'test_backend_qt4',
#      'test_backend_qt5',
#      'test_backend_svg',
#      'test_basic',
#      'test_bbox_tight',
#      'test_cbook',
#      'test_coding_standards',
#      'test_collections',
#      'test_colorbar',
#      'test_colors',
#      'test_compare_images',
#      'test_contour',
#      'test_dates',
#      'test_delaunay',
#      'test_dviread',
#      'test_figure',
#      'test_font_manager',
#      'test_gridspec',
#      'test_image',
#      'test_legend',
#      'test_lines',
#      'test_mathtext',
#      'test_mlab',
#      'test_patches',
#      'test_path',
#      'test_patheffects',
#      'test_pickle',
#      'test_png',
#      'test_quiver',
#      'test_rcparams',
#      'test_sankey',
#      'test_scale',
#      'test_simplification',
#      'test_skew',
#      'test_spines',
#      'test_streamplot',
#      'test_style',
#      'test_subplots',
#      'test_table',
#      'test_text',
#      'test_ticker',
#      'test_tightlayout',
#      'test_transforms',
#      'test_triangulation',
#      'test_ttconv'],
#     'name': 'matplotlib.tests',
#     'subpkgs': {},
#     'subpkgs_names': ['baseline_images']},
#    'tri': {'attr': 'subpk',
#     'modules_names': ['triangulation',
#      'tricontour',
#      'trifinder',
#      'triinterpolate',
#      'tripcolor',
#      'triplot',
#      'trirefine',
#      'tritools'],
#     'name': 'matplotlib.tri',
#     'subpkgs': {},
#     'subpkgs_names': []}},
#   'subpkgs_names': ['axes',
#    'backends',
#    'compat',
#    'delaunay',
#    'mpl-data',
#    'projections',
#    'sphinxext',
#    'style',
#    'testing',
#    'tests',
#    'tri']}}

# %%
[x for x in dir('matplotlib') if isinstance(getattr(x, name), types.ClassType)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-131-128ebb7149da> in <module>()
# ----> 1 [x for x in dir('matplotlib') if isinstance(getattr(x, name), types.ClassType)]
#
# NameError: name 'name' is not defined

# %% [markdown]
# Penser à se faire un notebook sur les notebook:
# * Spark et IPython
# * Gestion des variables : %reset => un d'afficher les noms et la mémoire occupée par chaque objet
# * Matplotlib magics
#
# Avec une partie utils avec des blocs de code qui servent :
# * checker les variables
# * printer des dataframes à la suite
# * explorer un package
# * etc.
